# %% [markdown]
# # 1. Data science workflow

# %% [markdown]
# ![workflow](imgs/data_science_workflow.png)
#
# ## We are going to focus on the "Wrangle->Clean->Explore" part.
# - "Data wrangling:" cleaning and unifying messy/complex data sets for easy access and analysis
# - The majority of a data scientists time is spent on data cleaning/wrangling!
# - "Garbage in/garbage out:"  Incorrect or poor quality input will always produce faulty output.  Examples:
#     - Some rows in a table are duplicated
#     - Some data entries are outside the realistic range (e.g. negative values for age)
#     - Data combined from two sources uses two different scales (e.g. celsius vs. Farenheit)
#
# ![pic](imgs/forbes_data_sci.jpg)
# [Source](https://www.forbes.com/sites/gilpress/2016/03/23/data-preparation-most-time-consuming-least-enjoyable-data-science-task-survey-says/#96b939c6f637)

# %% [markdown]
# # 2.  Setup - installing pandas

# %% [markdown]
# To use this pandas tutorial, we'll need to make sure we have access to:
# - python3
# - pandas library
# - Jupyter notebooks
#
# You have a few options:
# 1. Cloud environment (start here if you're not command line savvy and/or haven't used jupyter notebooks before):
#     - Use the JupyterLab binder button on the github repo. All of the dependencies are included in the environment.yml file used to build the binder container; you do not need to install anything on your computer.
# 2. Local environment, option 1:
#     - Clone the repo (`git clone https://github.com/bballew/pandas_tutorial.git`)
#     - Use conda (or your favorite package manager) to install the dependencies locally (`conda install -c bioconda <tool=version>`)
# 3. Local environment, option 2:
#     - Clone the repo (`git clone https://github.com/bballew/pandas_tutorial.git`)
#     - Use the environment file to build a conda environment locally (`conda env create -f environment.yml`)
#     - Be sure to start up jupyter notebook from within this environment!

# %% [markdown]
# # 3.  About pandas

# %% [markdown]
# ## What is pandas?
#
# - Package for cleaning, transforming, and analyzing your data
# - Built on top of NumPy, with additional functionality built in to deal with messier data
#     - Attach row and column labels
#     - Work with missing data
#     - Handle heterogeneous data types
#
# ## Why use pandas?
#
# - Have you ever used an Excel spreadsheet?  What were some of the ways you gleaned insights from your data?
#
# - Using pandas to clean and explore your data can be followed by application of machine learning models, or it can be a standalone analysis, depending on your needs

# %% [markdown]
# The two central components in pandas are the `series` and the `dataframe`.  A `series` is a column of data, and a `dataframe` is a table made up of a group of `series`.  Visually:
#
# __Series:__
#
# |Age|
# |---|
# |3|
# |7|
# |18|
# |54|
# |12|
#
# __Dataframe:__
#
# |Age|Sex|Height|
# |---|---|---|
# |3|M|36|
# |7|F|45|
# |18|F|60|
# |54|M|66|
# |12|M|58|

# %% [markdown]
# First, import the numpy and pandas libraries.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 4.  Building series and dataframes from scratch

# %% [markdown]
# To get started, let's build a couple series from numpy arrays.

# %%
age_array = np.array([3,7,18,54,12])
age_array
# Out:
# array([ 3,  7, 18, 54, 12])

# %%
age_series = pd.Series(age_array)
age_series
# Out:
# 0     3
# 1     7
# 2    18
# 3    54
# 4    12
# dtype: int64

# %%
sex_array = np.array(['M','F','F','M','M'])
sex_series = pd.Series(sex_array)
sex_series
# Out:
# 0    M
# 1    F
# 2    F
# 3    M
# 4    M
# dtype: object

# %% [markdown]
# Now, let's build a dataframe from scratch.  There are many ways to do this.  Let's first build a dataframe from a multidimensional numpy array.

# %%
df1 = pd.DataFrame(np.array([[3,7,18,54,12], ['M','F','F','M','M']]).T)
df1
# Out:
#     0  1
# 0   3  M
# 1   7  F
# 2  18  F
# 3  54  M
# 4  12  M

# %% [markdown]
# Alternatively, we could build a dataframe from scratch using a dict.  A dict is composed of __key:value__ pairs (in this case, the keys are age and sex; each has a single value which is a python list).

# %%
data = {
    'age': [3,7,18,54,12], 
    'sex': ['M','F','F','M','M']
}

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#    age sex
# 0    3   M
# 1    7   F
# 2   18   F
# 3   54   M
# 4   12   M

# %% [markdown]
# # 5.  Importing data

# %% [markdown]
# So, that's pretty cool, but it's unlikely that you'll want to manually type in your whole dataset as an array or a dict.  How can we read external data into a dataframe?  Let's say we have a tab-separated text file with data from an esophageal cancer project.

# %%
df_orig = pd.read_csv('data/esophageal_subjects.txt', sep='\t')
df_orig
# Out:
#        ID            Dx   AGE  SEX C3_EDUC  C16_HFUEL  D1_EVCIG  D2_START  \
# 0   PS002          ESCC  53.0    M       4        3.0         1      20.0
# 1   PS003          ESCC  63.0    F       6        7.0         2       NaN
# 2   PS005          HGIN  59.0    F       4        4.0         2       NaN
# 3   PS007          ESCC  69.0    F       5        7.0         2       NaN
# 4   PS007          ESCC  69.0    F       5        7.0         2       NaN
# 5   PS013          ESCC  67.0    M       .        7.0         1      36.0
# 6   PS015          HGIN  59.0    M       4        7.0         1      18.0
# 7   PS018          HGIN  58.0    M       3        4.0         1      26.0
# 8   PS019          HGIN  59.0    M       6        7.0         1      22.0
# 9   PS020          HGIN   NaN    M       6        7.0         1      22.0
# 10  PS021          HGIN  63.0    M       4        7.0         1      20.0
# 11  PS024          HGIN  50.0  NaN       3        NaN         1      20.0
# 12  PS025          HGIN  64.0    M       5        7.0         2       NaN
# 13  PS026          ESCC  66.0    F       3        7.0         2       NaN
# 14  PS028       Adenosq  54.0    M       4        1.0         1      18.0
# 15  PS030          ESCC  60.0    M       4        7.0         1      18.0
# 16  PS031          ESCC  59.0    M       5        7.0         1      20.0
# 17  PS032          ESCC  56.0    M       6        7.0         1      24.0
# 18  PS033          HGIN  47.0    M       5        1.0         1      25.0
# 19  PS034          ESCC  48.0    M      --        1.0         1      20.0
# 20  PS035          HGIN   NaN    M       4        1.0         1      22.0
# 21  PS036          ESCC  53.0    M       4        7.0         1      20.0
# 22  PS037          HGIN  53.0    M       5        7.0         1      22.0
# 23  PS039          ESCC  51.0    M       4        1.0         1      22.0
# 24  PS042          ESCC  67.0    M       4        1.0         1      21.0
# 25  PS046          ESCC  62.0    M       3        1.0         1      20.0
# 26  PS047  Adenosq_ESCC  72.0    M       5        1.0         2       NaN
# 27  PS049          HGIN  67.0    M       3        8.0         1      25.0
# 28  PS051          HGIN  52.0  NaN       6        1.0         1      18.0
# 29  PS054          HGIN  63.0    M       4        3.0         2       NaN
# 30  PS066          HGIN   NaN    M       5        7.0         1      18.0
# 31  PS067          ESCC  68.0    M       5        7.0         1      25.0
# 32  PS068          ESCC  53.0    M       6        1.0         1      22.0
# 33  PS070          HGIN  59.0    M       6        1.0         1      20.0
#
#     D4_STOP D5_NUMCIG  D8_LIQ E1_UGICAN  G1_TEMP  G2_SFREQ  H1_HEIGHT  \
# 0       NaN        20       5         2        4         4        170
# 1       NaN       NaN       5         1        4         4        161
# 2       NaN       NaN       5         2        4         3        159
# 3       NaN       NaN       5         2        4         4        160
# 4       NaN       NaN       5         2        4         4        160
# 5      57.0        20       1         2        2         2        184
# 6      57.0        15       1         1        2         1        176
# 7      58.0        20       1         2        3         4        170
# 8      55.0        20       1      None        3         4        172
# 9      65.0        30       1       NaN        3         4        177
# 10     63.0        20       1         2        2         1        773
# 11     50.0        20       5       NaN        4         4        169
# 12      NaN      None       2       NaN        2         4        167
# 13      NaN      None       5         2        2         1        160
# 14     54.0        60       2         2        4         4        175
# 15     30.0        40       4         2        4         4        173
# 16     55.0        20       2         2        3         4        173
# 17     55.0        20       3         2        4         3        175
# 18     45.0         8       1         2        4         4        180
# 19     47.0        20       1         2        4         4        176
# 20     46.0        40       1         2        3         4        170
# 21     53.0        40       1         1        4         4        176
# 22     53.0        20       1         2        4         4        172
# 23     50.0        10       3       NaN        3         4        170
# 24     65.0        20       1         2        4         4        179
# 25     62.0        30       1         2        2         1        177
# 26      NaN       NaN       4         1        2         1        183
# 27     47.0         3       1         1        2         1        177
# 28     50.0        40       1         1        4         4        170
# 29      NaN       NaN       5         2        4         4        170
# 30     59.0         6       1         2        4         4        180
# 31     35.0        20       1         1        4         4        173
# 32     53.0        35       1         1        4         4        176
# 33     59.0        20       1         1        4         3        170
#
#     H2_WEIGHT   PS_ID     WGS
# 0         110  PS-002  R12345
# 1          56  PS-003  R12346
# 2          63  PS-005  R12347
# 3         110  PS-007  R12348
# 4         110  PS-007  R12348
# 5         180  PS-013   R1223
# 6         150  PS-019   R1224
# 7         156  PS-021   R1225
# 8         130  PS-024   R1226
# 9         150  PS-026   R1227
# 10         75  PS-028   R1228
# 11         75  PS-030   R1229
# 12         63  PS-031   R126A
# 13         45  PS-032   R126B
# 14        150  PS-033   R126C
# 15        140  PS-034   R126D
# 16         75  PS-035   R126E
# 17         80  PS-039   R126F
# 18         85  PS-042   R126G
# 19         72  PS-046   R126H
# 20         74  PS-047   R126I
# 21        130  PS-049   R126J
# 22          5  PS-051   R126K
# 23        140  PS-066   R126L
# 24         80  PS-067   R126M
# 25         75  PS-068   R126N
# 26         88  PS-015   R126O
# 27         73  PS-018   R126P
# 28         75  PS-025   R126Q
# 29         63  PS-036   R126R
# 30         70  PS-037   R126S
# 31         63  PS-020   R126T
# 32         93  PS-054   R126U
# 33         79  PS-070   R126V

# %% [markdown]
# If you're running this notebook in Google Colab, use the following cell to pull in the data (this will also work in Binder).

# %%
url = 'https://raw.githubusercontent.com/bballew/pandas_tutorial/master/data/esophageal_subjects.txt'
df_orig = pd.read_csv(url, sep='\t')
df_orig
# Out:
#        ID            Dx   AGE  SEX C3_EDUC  C16_HFUEL  D1_EVCIG  D2_START  \
# 0   PS002          ESCC  53.0    M       4        3.0         1      20.0
# 1   PS003          ESCC  63.0    F       6        7.0         2       NaN
# 2   PS005          HGIN  59.0    F       4        4.0         2       NaN
# 3   PS007          ESCC  69.0    F       5        7.0         2       NaN
# 4   PS007          ESCC  69.0    F       5        7.0         2       NaN
# 5   PS013          ESCC  67.0    M       .        7.0         1      36.0
# 6   PS015          HGIN  59.0    M       4        7.0         1      18.0
# 7   PS018          HGIN  58.0    M       3        4.0         1      26.0
# 8   PS019          HGIN  59.0    M       6        7.0         1      22.0
# 9   PS020          HGIN   NaN    M       6        7.0         1      22.0
# 10  PS021          HGIN  63.0    M       4        7.0         1      20.0
# 11  PS024          HGIN  50.0  NaN       3        NaN         1      20.0
# 12  PS025          HGIN  64.0    M       5        7.0         2       NaN
# 13  PS026          ESCC  66.0    F       3        7.0         2       NaN
# 14  PS028       Adenosq  54.0    M       4        1.0         1      18.0
# 15  PS030          ESCC  60.0    M       4        7.0         1      18.0
# 16  PS031          ESCC  59.0    M       5        7.0         1      20.0
# 17  PS032          ESCC  56.0    M       6        7.0         1      24.0
# 18  PS033          HGIN  47.0    M       5        1.0         1      25.0
# 19  PS034          ESCC  48.0    M      --        1.0         1      20.0
# 20  PS035          HGIN   NaN    M       4        1.0         1      22.0
# 21  PS036          ESCC  53.0    M       4        7.0         1      20.0
# 22  PS037          HGIN  53.0    M       5        7.0         1      22.0
# 23  PS039          ESCC  51.0    M       4        1.0         1      22.0
# 24  PS042          ESCC  67.0    M       4        1.0         1      21.0
# 25  PS046          ESCC  62.0    M       3        1.0         1      20.0
# 26  PS047  Adenosq_ESCC  72.0    M       5        1.0         2       NaN
# 27  PS049          HGIN  67.0    M       3        8.0         1      25.0
# 28  PS051          HGIN  52.0  NaN       6        1.0         1      18.0
# 29  PS054          HGIN  63.0    M       4        3.0         2       NaN
# 30  PS066          HGIN   NaN    M       5        7.0         1      18.0
# 31  PS067          ESCC  68.0    M       5        7.0         1      25.0
# 32  PS068          ESCC  53.0    M       6        1.0         1      22.0
# 33  PS070          HGIN  59.0    M       6        1.0         1      20.0
#
#     D4_STOP D5_NUMCIG  D8_LIQ E1_UGICAN  G1_TEMP  G2_SFREQ  H1_HEIGHT  \
# 0       NaN        20       5         2        4         4        170
# 1       NaN       NaN       5         1        4         4        161
# 2       NaN       NaN       5         2        4         3        159
# 3       NaN       NaN       5         2        4         4        160
# 4       NaN       NaN       5         2        4         4        160
# 5      57.0        20       1         2        2         2        184
# 6      57.0        15       1         1        2         1        176
# 7      58.0        20       1         2        3         4        170
# 8      55.0        20       1      None        3         4        172
# 9      65.0        30       1       NaN        3         4        177
# 10     63.0        20       1         2        2         1        773
# 11     50.0        20       5       NaN        4         4        169
# 12      NaN      None       2       NaN        2         4        167
# 13      NaN      None       5         2        2         1        160
# 14     54.0        60       2         2        4         4        175
# 15     30.0        40       4         2        4         4        173
# 16     55.0        20       2         2        3         4        173
# 17     55.0        20       3         2        4         3        175
# 18     45.0         8       1         2        4         4        180
# 19     47.0        20       1         2        4         4        176
# 20     46.0        40       1         2        3         4        170
# 21     53.0        40       1         1        4         4        176
# 22     53.0        20       1         2        4         4        172
# 23     50.0        10       3       NaN        3         4        170
# 24     65.0        20       1         2        4         4        179
# 25     62.0        30       1         2        2         1        177
# 26      NaN       NaN       4         1        2         1        183
# 27     47.0         3       1         1        2         1        177
# 28     50.0        40       1         1        4         4        170
# 29      NaN       NaN       5         2        4         4        170
# 30     59.0         6       1         2        4         4        180
# 31     35.0        20       1         1        4         4        173
# 32     53.0        35       1         1        4         4        176
# 33     59.0        20       1         1        4         3        170
#
#     H2_WEIGHT   PS_ID     WGS
# 0         110  PS-002  R12345
# 1          56  PS-003  R12346
# 2          63  PS-005  R12347
# 3         110  PS-007  R12348
# 4         110  PS-007  R12348
# 5         180  PS-013   R1223
# 6         150  PS-019   R1224
# 7         156  PS-021   R1225
# 8         130  PS-024   R1226
# 9         150  PS-026   R1227
# 10         75  PS-028   R1228
# 11         75  PS-030   R1229
# 12         63  PS-031   R126A
# 13         45  PS-032   R126B
# 14        150  PS-033   R126C
# 15        140  PS-034   R126D
# 16         75  PS-035   R126E
# 17         80  PS-039   R126F
# 18         85  PS-042   R126G
# 19         72  PS-046   R126H
# 20         74  PS-047   R126I
# 21        130  PS-049   R126J
# 22          5  PS-051   R126K
# 23        140  PS-066   R126L
# 24         80  PS-067   R126M
# 25         75  PS-068   R126N
# 26         88  PS-015   R126O
# 27         73  PS-018   R126P
# 28         75  PS-025   R126Q
# 29         63  PS-036   R126R
# 30         70  PS-037   R126S
# 31         63  PS-020   R126T
# 32         93  PS-054   R126U
# 33         79  PS-070   R126V

# %% [markdown]
# # 6.  Viewing the dataframe

# %%
df_orig.head()
# Out:
#       ID    Dx   AGE SEX C3_EDUC  C16_HFUEL  D1_EVCIG  D2_START  D4_STOP  \
# 0  PS002  ESCC  53.0   M       4        3.0         1      20.0      NaN
# 1  PS003  ESCC  63.0   F       6        7.0         2       NaN      NaN
# 2  PS005  HGIN  59.0   F       4        4.0         2       NaN      NaN
# 3  PS007  ESCC  69.0   F       5        7.0         2       NaN      NaN
# 4  PS007  ESCC  69.0   F       5        7.0         2       NaN      NaN
#
#   D5_NUMCIG  D8_LIQ E1_UGICAN  G1_TEMP  G2_SFREQ  H1_HEIGHT  H2_WEIGHT  \
# 0        20       5         2        4         4        170        110
# 1       NaN       5         1        4         4        161         56
# 2       NaN       5         2        4         3        159         63
# 3       NaN       5         2        4         4        160        110
# 4       NaN       5         2        4         4        160        110
#
#     PS_ID     WGS
# 0  PS-002  R12345
# 1  PS-003  R12346
# 2  PS-005  R12347
# 3  PS-007  R12348
# 4  PS-007  R12348

# %% [markdown]
# __Exercise: First, put the cursor in the following cell, then press `shift + TAB`.  If that does nothing, prepend the cell with a '?' and run it.  Depending on your environment, one of these two options will pull up documentation.  Then, edit the cell to view the first 10 lines of the dataframe__

# %%
# ?df_orig.head()
df_orig.head(10)
# Out:
#       ID    Dx   AGE SEX C3_EDUC  C16_HFUEL  D1_EVCIG  D2_START  D4_STOP  \
# 0  PS002  ESCC  53.0   M       4        3.0         1      20.0      NaN
# 1  PS003  ESCC  63.0   F       6        7.0         2       NaN      NaN
# 2  PS005  HGIN  59.0   F       4        4.0         2       NaN      NaN
# 3  PS007  ESCC  69.0   F       5        7.0         2       NaN      NaN
# 4  PS007  ESCC  69.0   F       5        7.0         2       NaN      NaN
# 5  PS013  ESCC  67.0   M       .        7.0         1      36.0     57.0
# 6  PS015  HGIN  59.0   M       4        7.0         1      18.0     57.0
# 7  PS018  HGIN  58.0   M       3        4.0         1      26.0     58.0
# 8  PS019  HGIN  59.0   M       6        7.0         1      22.0     55.0
# 9  PS020  HGIN   NaN   M       6        7.0         1      22.0     65.0
#
#   D5_NUMCIG  D8_LIQ E1_UGICAN  G1_TEMP  G2_SFREQ  H1_HEIGHT  H2_WEIGHT  \
# 0        20       5         2        4         4        170        110
# 1       NaN       5         1        4         4        161         56
# 2       NaN       5         2        4         3        159         63
# 3       NaN       5         2        4         4        160        110
# 4       NaN       5         2        4         4        160        110
# 5        20       1         2        2         2        184        180
# 6        15       1         1        2         1        176        150
# 7        20       1         2        3         4        170        156
# 8        20       1      None        3         4        172        130
# 9        30       1       NaN        3         4        177        150
#
#     PS_ID     WGS
# 0  PS-002  R12345
# 1  PS-003  R12346
# 2  PS-005  R12347
# 3  PS-007  R12348
# 4  PS-007  R12348
# 5  PS-013   R1223
# 6  PS-019   R1224
# 7  PS-021   R1225
# 8  PS-024   R1226
# 9  PS-026   R1227

# %%
df_orig.tail()
# Out:
#        ID    Dx   AGE SEX C3_EDUC  C16_HFUEL  D1_EVCIG  D2_START  D4_STOP  \
# 29  PS054  HGIN  63.0   M       4        3.0         2       NaN      NaN
# 30  PS066  HGIN   NaN   M       5        7.0         1      18.0     59.0
# 31  PS067  ESCC  68.0   M       5        7.0         1      25.0     35.0
# 32  PS068  ESCC  53.0   M       6        1.0         1      22.0     53.0
# 33  PS070  HGIN  59.0   M       6        1.0         1      20.0     59.0
#
#    D5_NUMCIG  D8_LIQ E1_UGICAN  G1_TEMP  G2_SFREQ  H1_HEIGHT  H2_WEIGHT  \
# 29       NaN       5         2        4         4        170         63
# 30         6       1         2        4         4        180         70
# 31        20       1         1        4         4        173         63
# 32        35       1         1        4         4        176         93
# 33        20       1         1        4         3        170         79
#
#      PS_ID    WGS
# 29  PS-036  R126R
# 30  PS-037  R126S
# 31  PS-020  R126T
# 32  PS-054  R126U
# 33  PS-070  R126V

# %%
df_orig.shape
# Out:
# (34, 18)

# %%
df_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 18 columns):
# ID           34 non-null object
# Dx           34 non-null object
# AGE          31 non-null float64
# SEX          32 non-null object
# C3_EDUC      34 non-null object
# C16_HFUEL    33 non-null float64
# D1_EVCIG     34 non-null int64
# D2_START     26 non-null float64
# D4_STOP      25 non-null float64
# D5_NUMCIG    28 non-null object
# D8_LIQ       34 non-null int64
# E1_UGICAN    30 non-null object
# G1_TEMP      34 non-null int64
# G2_SFREQ     34 non-null int64
# H1_HEIGHT    34 non-null int64
# H2_WEIGHT    34 non-null int64
# PS_ID        34 non-null object
# WGS          34 non-null object
# dtypes: float64(4), int64(6), object(8)
# memory usage: 4.9+ KB

# %% [markdown]
# Note the data types reported above.  For example, 'C3_EDUC' looks like a column of numbers, but the dtype is reported as "object", which is a string.  This is a clue that something might be awry in this column (for example, there may be a missing value that is noted with a string like 'na').

# %% [markdown]
# Count non-null values by column.

# %%
df_orig.count()
# Out:
# ID           34
# Dx           34
# AGE          31
# SEX          32
# C3_EDUC      34
# C16_HFUEL    33
# D1_EVCIG     34
# D2_START     26
# D4_STOP      25
# D5_NUMCIG    28
# D8_LIQ       34
# E1_UGICAN    30
# G1_TEMP      34
# G2_SFREQ     34
# H1_HEIGHT    34
# H2_WEIGHT    34
# PS_ID        34
# WGS          34
# dtype: int64

# %% [markdown]
# Count distinct values by column.  Check here that columns have the expected number of unique values, e.g. two values for sex.

# %%
df_orig.nunique()
# Out:
# ID           33
# Dx            4
# AGE          19
# SEX           2
# C3_EDUC       6
# C16_HFUEL     5
# D1_EVCIG      2
# D2_START      8
# D4_STOP      15
# D5_NUMCIG    11
# D8_LIQ        5
# E1_UGICAN     3
# G1_TEMP       3
# G2_SFREQ      4
# H1_HEIGHT    16
# H2_WEIGHT    20
# PS_ID        33
# WGS          33
# dtype: int64

# %% [markdown]
# # 7.  Slicing and extracting data

# %% [markdown]
# You will see some of these techniques in action shortly, but let's take a moment for an introduction.  You can subset a dataframe in several ways, and the subsetted data can be either a dataframe or a series.

# %% [markdown]
# First, let's subset by column name.  Notice that this results in a series.

# %%
df_orig['AGE']
# Out:
# 0     53.0
# 1     63.0
# 2     59.0
# 3     69.0
# 4     69.0
# 5     67.0
# 6     59.0
# 7     58.0
# 8     59.0
# 9      NaN
# 10    63.0
# 11    50.0
# 12    64.0
# 13    66.0
# 14    54.0
# 15    60.0
# 16    59.0
# 17    56.0
# 18    47.0
# 19    48.0
# 20     NaN
# 21    53.0
# 22    53.0
# 23    51.0
# 24    67.0
# 25    62.0
# 26    72.0
# 27    67.0
# 28    52.0
# 29    63.0
# 30     NaN
# 31    68.0
# 32    53.0
# 33    59.0
# Name: AGE, dtype: float64

# %%
type(df_orig['AGE'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# You can subset by column name and get a dataframe by passing a list.

# %%
df_orig[['AGE']]
# Out:
#      AGE
# 0   53.0
# 1   63.0
# 2   59.0
# 3   69.0
# 4   69.0
# 5   67.0
# 6   59.0
# 7   58.0
# 8   59.0
# 9    NaN
# 10  63.0
# 11  50.0
# 12  64.0
# 13  66.0
# 14  54.0
# 15  60.0
# 16  59.0
# 17  56.0
# 18  47.0
# 19  48.0
# 20   NaN
# 21  53.0
# 22  53.0
# 23  51.0
# 24  67.0
# 25  62.0
# 26  72.0
# 27  67.0
# 28  52.0
# 29  63.0
# 30   NaN
# 31  68.0
# 32  53.0
# 33  59.0

# %%
type(df_orig[['AGE']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# You can easily subset a dataframe by multiple columns, by adding column names to the list.

# %%
df_orig[['AGE','H2_WEIGHT']]
# Out:
#      AGE  H2_WEIGHT
# 0   53.0        110
# 1   63.0         56
# 2   59.0         63
# 3   69.0        110
# 4   69.0        110
# 5   67.0        180
# 6   59.0        150
# 7   58.0        156
# 8   59.0        130
# 9    NaN        150
# 10  63.0         75
# 11  50.0         75
# 12  64.0         63
# 13  66.0         45
# 14  54.0        150
# 15  60.0        140
# 16  59.0         75
# 17  56.0         80
# 18  47.0         85
# 19  48.0         72
# 20   NaN         74
# 21  53.0        130
# 22  53.0          5
# 23  51.0        140
# 24  67.0         80
# 25  62.0         75
# 26  72.0         88
# 27  67.0         73
# 28  52.0         75
# 29  63.0         63
# 30   NaN         70
# 31  68.0         63
# 32  53.0         93
# 33  59.0         79

# %% [markdown]
# You can also extract data from rows in the dataframe by index or by label, using `.loc` and `.iloc`.

# %%
df_orig.loc[0]  # if we had set data labels other than index number, we would use df_orig.loc['myRowLabel'] here.
# Out:
# ID            PS002
# Dx             ESCC
# AGE              53
# SEX               M
# C3_EDUC           4
# C16_HFUEL         3
# D1_EVCIG          1
# D2_START         20
# D4_STOP         NaN
# D5_NUMCIG        20
# D8_LIQ            5
# E1_UGICAN         2
# G1_TEMP           4
# G2_SFREQ          4
# H1_HEIGHT       170
# H2_WEIGHT       110
# PS_ID        PS-002
# WGS          R12345
# Name: 0, dtype: object

# %%
df_orig.iloc[0]
# Out:
# ID            PS002
# Dx             ESCC
# AGE              53
# SEX               M
# C3_EDUC           4
# C16_HFUEL         3
# D1_EVCIG          1
# D2_START         20
# D4_STOP         NaN
# D5_NUMCIG        20
# D8_LIQ            5
# E1_UGICAN         2
# G1_TEMP           4
# G2_SFREQ          4
# H1_HEIGHT       170
# H2_WEIGHT       110
# PS_ID        PS-002
# WGS          R12345
# Name: 0, dtype: object

# %% [markdown]
# As with columns, the above methods give you a series.  You can get a dataframe by providing a list.

# %%
df_orig.loc[[0]]
# Out:
#       ID    Dx   AGE SEX C3_EDUC  C16_HFUEL  D1_EVCIG  D2_START  D4_STOP  \
# 0  PS002  ESCC  53.0   M       4        3.0         1      20.0      NaN
#
#   D5_NUMCIG  D8_LIQ E1_UGICAN  G1_TEMP  G2_SFREQ  H1_HEIGHT  H2_WEIGHT  \
# 0        20       5         2        4         4        170        110
#
#     PS_ID     WGS
# 0  PS-002  R12345

# %% [markdown]
# __Exercise: Look at the column headers in df_orig by using `.columns`, then select one to extract from the dataframe.  How do you extract the data as a series?  As a dataframe?__

# %%
df_orig.columns
# Out:
# Index(['ID', 'Dx', 'AGE', 'SEX', 'C3_EDUC', 'C16_HFUEL', 'D1_EVCIG',
#        'D2_START', 'D4_STOP', 'D5_NUMCIG', 'D8_LIQ', 'E1_UGICAN', 'G1_TEMP',
#        'G2_SFREQ', 'H1_HEIGHT', 'H2_WEIGHT', 'PS_ID', 'WGS'],
#       dtype='object')

# %%
df_orig[['G2_SFREQ']]
# Out:
#     G2_SFREQ
# 0          4
# 1          4
# 2          3
# 3          4
# 4          4
# 5          2
# 6          1
# 7          4
# 8          4
# 9          4
# 10         1
# 11         4
# 12         4
# 13         1
# 14         4
# 15         4
# 16         4
# 17         3
# 18         4
# 19         4
# 20         4
# 21         4
# 22         4
# 23         4
# 24         4
# 25         1
# 26         1
# 27         1
# 28         4
# 29         4
# 30         4
# 31         4
# 32         4
# 33         3

# %%
df_orig['G2_SFREQ']
# Out:
# 0     4
# 1     4
# 2     3
# 3     4
# 4     4
# 5     2
# 6     1
# 7     4
# 8     4
# 9     4
# 10    1
# 11    4
# 12    4
# 13    1
# 14    4
# 15    4
# 16    4
# 17    3
# 18    4
# 19    4
# 20    4
# 21    4
# 22    4
# 23    4
# 24    4
# 25    1
# 26    1
# 27    1
# 28    4
# 29    4
# 30    4
# 31    4
# 32    4
# 33    3
# Name: G2_SFREQ, dtype: int64

# %% [markdown]
# # 8.  Clean up the data

# %% [markdown]
# ## 8.1.  Remove duplicate values

# %% [markdown]
# You may want to check your data for duplicate entries.  Using `drop_duplicates()`, we can remove all duplicate rows, or keep only the first or last row of a set of duplicates.  Here, we remove a row in which all values are duplicates of another row.

# %%
df_clean = df_orig.copy()
df_clean.head()
# Out:
#       ID    Dx   AGE SEX C3_EDUC  C16_HFUEL  D1_EVCIG  D2_START  D4_STOP  \
# 0  PS002  ESCC  53.0   M       4        3.0         1      20.0      NaN
# 1  PS003  ESCC  63.0   F       6        7.0         2       NaN      NaN
# 2  PS005  HGIN  59.0   F       4        4.0         2       NaN      NaN
# 3  PS007  ESCC  69.0   F       5        7.0         2       NaN      NaN
# 4  PS007  ESCC  69.0   F       5        7.0         2       NaN      NaN
#
#   D5_NUMCIG  D8_LIQ E1_UGICAN  G1_TEMP  G2_SFREQ  H1_HEIGHT  H2_WEIGHT  \
# 0        20       5         2        4         4        170        110
# 1       NaN       5         1        4         4        161         56
# 2       NaN       5         2        4         3        159         63
# 3       NaN       5         2        4         4        160        110
# 4       NaN       5         2        4         4        160        110
#
#     PS_ID     WGS
# 0  PS-002  R12345
# 1  PS-003  R12346
# 2  PS-005  R12347
# 3  PS-007  R12348
# 4  PS-007  R12348

# %%
df_clean.sort_values("ID", inplace = True)
df_clean.drop_duplicates(keep = 'first', inplace = True)

# %%
df_clean.shape
# Out:
# (33, 18)

# %% [markdown]
# We can also remove duplicates based on specific values, like "Dx".  In this example, we keep only the last row of each duplicate diagnosis.

# %%
df_Dx = df_clean.sort_values('Dx')
df_Dx.drop_duplicates(subset = 'Dx', keep = 'last', inplace = True)
df_Dx.shape
# Out:
# (4, 18)

# %%
df_Dx
# Out:
#        ID            Dx   AGE SEX C3_EDUC  C16_HFUEL  D1_EVCIG  D2_START  \
# 14  PS028       Adenosq  54.0   M       4        1.0         1      18.0
# 26  PS047  Adenosq_ESCC  72.0   M       5        1.0         2       NaN
# 13  PS026          ESCC  66.0   F       3        7.0         2       NaN
# 33  PS070          HGIN  59.0   M       6        1.0         1      20.0
#
#     D4_STOP D5_NUMCIG  D8_LIQ E1_UGICAN  G1_TEMP  G2_SFREQ  H1_HEIGHT  \
# 14     54.0        60       2         2        4         4        175
# 26      NaN       NaN       4         1        2         1        183
# 13      NaN      None       5         2        2         1        160
# 33     59.0        20       1         1        4         3        170
#
#     H2_WEIGHT   PS_ID    WGS
# 14        150  PS-033  R126C
# 26         88  PS-015  R126O
# 13         45  PS-032  R126B
# 33         79  PS-070  R126V

# %% [markdown]
# __Exercise: Copy the dataframe df_orig, sort the copy by sex, drop all but the first duplicates, and determine the shape__

# %%
df_exercise = df_orig.copy()
df_exercise.sort_values('SEX',inplace=True)
df_exercise.drop_duplicates(subset='SEX', keep='first',inplace=True)
df_exercise.shape
# Out:
# (3, 18)

# %% [markdown]
# ## 8.2.  Modify column headings and row labels

# %% [markdown]
# Let's look at the column headings in our data.

# %%
df_clean.columns
# Out:
# Index(['ID', 'Dx', 'AGE', 'SEX', 'C3_EDUC', 'C16_HFUEL', 'D1_EVCIG',
#        'D2_START', 'D4_STOP', 'D5_NUMCIG', 'D8_LIQ', 'E1_UGICAN', 'G1_TEMP',
#        'G2_SFREQ', 'H1_HEIGHT', 'H2_WEIGHT', 'PS_ID', 'WGS'],
#       dtype='object')

# %% [markdown]
# The columns headings on our imported data are difficult to interpret.  Let's change them to something that makes more sense.

# %%
df_clean.rename(columns={'C3_EDUC':'Education_level',
                   'C16_HFUEL':'Heating_source',
                   'D1_EVCIG':'Smoke_6mos',
                   'D2_START':'Age_start_smoking',
                   'D4_STOP':'Age_stop_smoking',
                   'D5_NUMCIG':'Cigarettes_per_day',
                   'D8_LIQ':'Liquor_freq',
                   'E1_UGICAN':'Family_hx_UGIcancer',
                   'G1_TEMP':'Temp_of_hot_beverages',
                   'G2_SFREQ':'Frequency_scalding_food',
                   'H1_HEIGHT':'Height_cm',
                   'H2_WEIGHT':'Weight_kg'},
         inplace=True)

# %%
df_clean.head()
# Out:
#       ID    Dx   AGE SEX Education_level  Heating_source  Smoke_6mos  \
# 0  PS002  ESCC  53.0   M               4             3.0           1
# 1  PS003  ESCC  63.0   F               6             7.0           2
# 2  PS005  HGIN  59.0   F               4             4.0           2
# 3  PS007  ESCC  69.0   F               5             7.0           2
# 5  PS013  ESCC  67.0   M               .             7.0           1
#
#    Age_start_smoking  Age_stop_smoking Cigarettes_per_day  Liquor_freq  \
# 0               20.0               NaN                 20            5
# 1                NaN               NaN                NaN            5
# 2                NaN               NaN                NaN            5
# 3                NaN               NaN                NaN            5
# 5               36.0              57.0                 20            1
#
#   Family_hx_UGIcancer  Temp_of_hot_beverages  Frequency_scalding_food  \
# 0                   2                      4                        4
# 1                   1                      4                        4
# 2                   2                      4                        3
# 3                   2                      4                        4
# 5                   2                      2                        2
#
#    Height_cm  Weight_kg   PS_ID     WGS
# 0        170        110  PS-002  R12345
# 1        161         56  PS-003  R12346
# 2        159         63  PS-005  R12347
# 3        160        110  PS-007  R12348
# 5        184        180  PS-013   R1223

# %% [markdown]
# We could also change the column headings using `.columns`.  Let's say we wanted a dataframe with only lowercase column headings.

# %%
df_clean.columns = ['id', 'dx', 'age', 'sex', 'education_level', 'heating_source',
       'smoke_6mos', 'age_start_smoking', 'age_stop_smoking',
       'cigarettes_per_day', 'liquor_freq', 'family_hx_ugicancer',
       'temp_of_hot_beverages', 'frequency_scalding_food', 'height_cm',
       'weight_kg', 'ps_id', 'wgs']

# %%
df_clean.head()
# Out:
#       id    dx   age sex education_level  heating_source  smoke_6mos  \
# 0  PS002  ESCC  53.0   M               4             3.0           1
# 1  PS003  ESCC  63.0   F               6             7.0           2
# 2  PS005  HGIN  59.0   F               4             4.0           2
# 3  PS007  ESCC  69.0   F               5             7.0           2
# 5  PS013  ESCC  67.0   M               .             7.0           1
#
#    age_start_smoking  age_stop_smoking cigarettes_per_day  liquor_freq  \
# 0               20.0               NaN                 20            5
# 1                NaN               NaN                NaN            5
# 2                NaN               NaN                NaN            5
# 3                NaN               NaN                NaN            5
# 5               36.0              57.0                 20            1
#
#   family_hx_ugicancer  temp_of_hot_beverages  frequency_scalding_food  \
# 0                   2                      4                        4
# 1                   1                      4                        4
# 2                   2                      4                        3
# 3                   2                      4                        4
# 5                   2                      2                        2
#
#    height_cm  weight_kg   ps_id     wgs
# 0        170        110  PS-002  R12345
# 1        161         56  PS-003  R12346
# 2        159         63  PS-005  R12347
# 3        160        110  PS-007  R12348
# 5        184        180  PS-013   R1223

# %% [markdown]
# Our row labels right now are just numbered, i.e. 0,1,2...  Let's change the row labels to the patient IDs.

# %%
df_clean.set_index('id', inplace=True)

# %%
df_clean.head()
# Out:
#          dx   age sex education_level  heating_source  smoke_6mos  \
# id
# PS002  ESCC  53.0   M               4             3.0           1
# PS003  ESCC  63.0   F               6             7.0           2
# PS005  HGIN  59.0   F               4             4.0           2
# PS007  ESCC  69.0   F               5             7.0           2
# PS013  ESCC  67.0   M               .             7.0           1
#
#        age_start_smoking  age_stop_smoking cigarettes_per_day  liquor_freq  \
# id
# PS002               20.0               NaN                 20            5
# PS003                NaN               NaN                NaN            5
# PS005                NaN               NaN                NaN            5
# PS007                NaN               NaN                NaN            5
# PS013               36.0              57.0                 20            1
#
#       family_hx_ugicancer  temp_of_hot_beverages  frequency_scalding_food  \
# id
# PS002                   2                      4                        4
# PS003                   1                      4                        4
# PS005                   2                      4                        3
# PS007                   2                      4                        4
# PS013                   2                      2                        2
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002        170        110  PS-002  R12345
# PS003        161         56  PS-003  R12346
# PS005        159         63  PS-005  R12347
# PS007        160        110  PS-007  R12348
# PS013        184        180  PS-013   R1223

# %% [markdown]
# ## 8.3.  Re-coding data

# %% [markdown]
# This data has many encoded values, e.g. integers that represent various levels of education, heating fuel types, etc.  Let's replace the encoded data with the real data.

# %%
df_clean.columns
# Out:
# Index(['dx', 'age', 'sex', 'education_level', 'heating_source', 'smoke_6mos',
#        'age_start_smoking', 'age_stop_smoking', 'cigarettes_per_day',
#        'liquor_freq', 'family_hx_ugicancer', 'temp_of_hot_beverages',
#        'frequency_scalding_food', 'height_cm', 'weight_kg', 'ps_id', 'wgs'],
#       dtype='object')

# %%
df_clean['education_level'].replace(['1','2','3','4','5','6','7'],['None','1-5yrs','Primary','Middle','High','College','Other'], inplace=True)
df_clean['heating_source'].replace([1,2,3,4,5,6,7,8],['Coal','Coke','Coal_product','Firewood','Diesel','Kerosene','Gas','Other'], inplace=True)
df_clean['smoke_6mos'].replace([1,2],['Yes','No'], inplace=True)
df_clean['liquor_freq'].replace([1,2,3,4,5],['Daily','Weekly','Monthly','Seasonally','Rarely-never'], inplace = True)
df_clean['family_hx_ugicancer'].replace(['1','2'],['Yes','No'], inplace = True)
df_clean['temp_of_hot_beverages'].replace([1,2,3,4,9],['Cool','Warm','Hot','Scalding','DK'], inplace=True)
df_clean['frequency_scalding_food'].replace([1,2,3,4,9],['Seldom-never','Occasionally','Weekly','Daily','DK'], inplace=True)

# %% [markdown]
# What's the deal with `[1,2,3,]` vs. `['1','2','3']` above?  Recall the result of `.info()`.  Columns that contain only integers like 1,2,3 are of an integer dtype.  However, if there are mixed types within the column (e.g. a missing value like '.' or 'Nan'), then the column will be an object type, which are strings.

# %%
df_clean.head()
# Out:
#          dx   age sex education_level heating_source smoke_6mos  \
# id
# PS002  ESCC  53.0   M          Middle   Coal_product        Yes
# PS003  ESCC  63.0   F         College            Gas         No
# PS005  HGIN  59.0   F          Middle       Firewood         No
# PS007  ESCC  69.0   F            High            Gas         No
# PS013  ESCC  67.0   M               .            Gas        Yes
#
#        age_start_smoking  age_stop_smoking cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0               NaN                 20  Rarely-never
# PS003                NaN               NaN                NaN  Rarely-never
# PS005                NaN               NaN                NaN  Rarely-never
# PS007                NaN               NaN                NaN  Rarely-never
# PS013               36.0              57.0                 20         Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
# PS003                 Yes              Scalding                   Daily
# PS005                  No              Scalding                  Weekly
# PS007                  No              Scalding                   Daily
# PS013                  No                  Warm            Occasionally
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002        170        110  PS-002  R12345
# PS003        161         56  PS-003  R12346
# PS005        159         63  PS-005  R12347
# PS007        160        110  PS-007  R12348
# PS013        184        180  PS-013   R1223

# %% [markdown]
# __Exercise: Copy df_clean and replace 'M' and 'F' with 'male' and 'female', then show the first 5 rows__

# %%
df_ex2 = df_clean.copy()
df_ex2['sex'].replace(['M','F'],['male','female'],inplace=True)
df_ex2.head()
# Out:
#          dx   age     sex education_level heating_source smoke_6mos  \
# id
# PS002  ESCC  53.0    male          Middle   Coal_product        Yes
# PS003  ESCC  63.0  female         College            Gas         No
# PS005  HGIN  59.0  female          Middle       Firewood         No
# PS007  ESCC  69.0  female            High            Gas         No
# PS013  ESCC  67.0    male               .            Gas        Yes
#
#        age_start_smoking  age_stop_smoking cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0               NaN                 20  Rarely-never
# PS003                NaN               NaN                NaN  Rarely-never
# PS005                NaN               NaN                NaN  Rarely-never
# PS007                NaN               NaN                NaN  Rarely-never
# PS013               36.0              57.0                 20         Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
# PS003                 Yes              Scalding                   Daily
# PS005                  No              Scalding                  Weekly
# PS007                  No              Scalding                   Daily
# PS013                  No                  Warm            Occasionally
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002        170        110  PS-002  R12345
# PS003        161         56  PS-003  R12346
# PS005        159         63  PS-005  R12347
# PS007        160        110  PS-007  R12348
# PS013        184        180  PS-013   R1223

# %% [markdown]
# ## 8.4.  Missing values

# %% [markdown]
# Datasets often have missing values.  These can be annotated in a variety of ways - 'None', 'NaN', 'na', '.', a blank space...  These must first be identified.  Then, we can either drop the relevant rows/columns, or replace the missing values with something (often the mean or median of the column).  Some pandas techniques will handle missing values by simply omitting them from the calculation, so depending on what you're doing, you may be able to tolerate some missingness.

# %%
df_clean.isnull()
# Out:
#           dx    age    sex  education_level  heating_source  smoke_6mos  \
# id
# PS002  False  False  False            False           False       False
# PS003  False  False  False            False           False       False
# PS005  False  False  False            False           False       False
# PS007  False  False  False            False           False       False
# PS013  False  False  False            False           False       False
# PS015  False  False  False            False           False       False
# PS018  False  False  False            False           False       False
# PS019  False  False  False            False           False       False
# PS020  False   True  False            False           False       False
# PS021  False  False  False            False           False       False
# PS024  False  False   True            False            True       False
# PS025  False  False  False            False           False       False
# PS026  False  False  False            False           False       False
# PS028  False  False  False            False           False       False
# PS030  False  False  False            False           False       False
# PS031  False  False  False            False           False       False
# PS032  False  False  False            False           False       False
# PS033  False  False  False            False           False       False
# PS034  False  False  False            False           False       False
# PS035  False   True  False            False           False       False
# PS036  False  False  False            False           False       False
# PS037  False  False  False            False           False       False
# PS039  False  False  False            False           False       False
# PS042  False  False  False            False           False       False
# PS046  False  False  False            False           False       False
# PS047  False  False  False            False           False       False
# PS049  False  False  False            False           False       False
# PS051  False  False   True            False           False       False
# PS054  False  False  False            False           False       False
# PS066  False   True  False            False           False       False
# PS067  False  False  False            False           False       False
# PS068  False  False  False            False           False       False
# PS070  False  False  False            False           False       False
#
#        age_start_smoking  age_stop_smoking  cigarettes_per_day  liquor_freq  \
# id
# PS002              False              True               False        False
# PS003               True              True                True        False
# PS005               True              True                True        False
# PS007               True              True                True        False
# PS013              False             False               False        False
# PS015              False             False               False        False
# PS018              False             False               False        False
# PS019              False             False               False        False
# PS020              False             False               False        False
# PS021              False             False               False        False
# PS024              False             False               False        False
# PS025               True              True               False        False
# PS026               True              True               False        False
# PS028              False             False               False        False
# PS030              False             False               False        False
# PS031              False             False               False        False
# PS032              False             False               False        False
# PS033              False             False               False        False
# PS034              False             False               False        False
# PS035              False             False               False        False
# PS036              False             False               False        False
# PS037              False             False               False        False
# PS039              False             False               False        False
# PS042              False             False               False        False
# PS046              False             False               False        False
# PS047               True              True                True        False
# PS049              False             False               False        False
# PS051              False             False               False        False
# PS054               True              True                True        False
# PS066              False             False               False        False
# PS067              False             False               False        False
# PS068              False             False               False        False
# PS070              False             False               False        False
#
#        family_hx_ugicancer  temp_of_hot_beverages  frequency_scalding_food  \
# id
# PS002                False                  False                    False
# PS003                False                  False                    False
# PS005                False                  False                    False
# PS007                False                  False                    False
# PS013                False                  False                    False
# PS015                False                  False                    False
# PS018                False                  False                    False
# PS019                False                  False                    False
# PS020                 True                  False                    False
# PS021                False                  False                    False
# PS024                 True                  False                    False
# PS025                 True                  False                    False
# PS026                False                  False                    False
# PS028                False                  False                    False
# PS030                False                  False                    False
# PS031                False                  False                    False
# PS032                False                  False                    False
# PS033                False                  False                    False
# PS034                False                  False                    False
# PS035                False                  False                    False
# PS036                False                  False                    False
# PS037                False                  False                    False
# PS039                 True                  False                    False
# PS042                False                  False                    False
# PS046                False                  False                    False
# PS047                False                  False                    False
# PS049                False                  False                    False
# PS051                False                  False                    False
# PS054                False                  False                    False
# PS066                False                  False                    False
# PS067                False                  False                    False
# PS068                False                  False                    False
# PS070                False                  False                    False
#
#        height_cm  weight_kg  ps_id    wgs
# id
# PS002      False      False  False  False
# PS003      False      False  False  False
# PS005      False      False  False  False
# PS007      False      False  False  False
# PS013      False      False  False  False
# PS015      False      False  False  False
# PS018      False      False  False  False
# PS019      False      False  False  False
# PS020      False      False  False  False
# PS021      False      False  False  False
# PS024      False      False  False  False
# PS025      False      False  False  False
# PS026      False      False  False  False
# PS028      False      False  False  False
# PS030      False      False  False  False
# PS031      False      False  False  False
# PS032      False      False  False  False
# PS033      False      False  False  False
# PS034      False      False  False  False
# PS035      False      False  False  False
# PS036      False      False  False  False
# PS037      False      False  False  False
# PS039      False      False  False  False
# PS042      False      False  False  False
# PS046      False      False  False  False
# PS047      False      False  False  False
# PS049      False      False  False  False
# PS051      False      False  False  False
# PS054      False      False  False  False
# PS066      False      False  False  False
# PS067      False      False  False  False
# PS068      False      False  False  False
# PS070      False      False  False  False

# %%
df_clean.isnull().sum()
# Out:
# dx                         0
# age                        3
# sex                        2
# education_level            0
# heating_source             1
# smoke_6mos                 0
# age_start_smoking          7
# age_stop_smoking           8
# cigarettes_per_day         5
# liquor_freq                0
# family_hx_ugicancer        4
# temp_of_hot_beverages      0
# frequency_scalding_food    0
# height_cm                  0
# weight_kg                  0
# ps_id                      0
# wgs                        0
# dtype: int64

# %% [markdown]
# __Exercise: Use `shift + TAB` or prepend with a `?` to look at the docustring for `.sum()`.  How would we get the sum of null values in each row, instead of each column?__

# %%
# ?df_clean.sum()
df_clean.isnull().sum(axis=1)
# Out:
# id
# PS002    1
# PS003    3
# PS005    3
# PS007    3
# PS013    0
# PS015    0
# PS018    0
# PS019    0
# PS020    2
# PS021    0
# PS024    3
# PS025    3
# PS026    2
# PS028    0
# PS030    0
# PS031    0
# PS032    0
# PS033    0
# PS034    0
# PS035    1
# PS036    0
# PS037    0
# PS039    1
# PS042    0
# PS046    0
# PS047    3
# PS049    0
# PS051    1
# PS054    3
# PS066    1
# PS067    0
# PS068    0
# PS070    0
# dtype: int64

# %% [markdown]
# Let's take a closer look.  What type of "missing" values does `isnull()` detect?

# %%
df_clean['education_level']
# Out:
# id
# PS002     Middle
# PS003    College
# PS005     Middle
# PS007       High
# PS013          .
# PS015     Middle
# PS018    Primary
# PS019    College
# PS020    College
# PS021     Middle
# PS024    Primary
# PS025       High
# PS026    Primary
# PS028     Middle
# PS030     Middle
# PS031       High
# PS032    College
# PS033       High
# PS034         --
# PS035     Middle
# PS036     Middle
# PS037       High
# PS039     Middle
# PS042     Middle
# PS046    Primary
# PS047       High
# PS049    Primary
# PS051    College
# PS054     Middle
# PS066       High
# PS067       High
# PS068    College
# PS070    College
# Name: education_level, dtype: object

# %%
df_clean['education_level'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Hmm...`isnull()` doesn't recognize all of our missing values.  We'll need to address this by normalizing all the missing values that we can find.

# %%
df_clean.replace(['None','.','--','na'],np.nan, inplace=True)

# %%
df_clean['education_level']
# Out:
# id
# PS002     Middle
# PS003    College
# PS005     Middle
# PS007       High
# PS013        NaN
# PS015     Middle
# PS018    Primary
# PS019    College
# PS020    College
# PS021     Middle
# PS024    Primary
# PS025       High
# PS026    Primary
# PS028     Middle
# PS030     Middle
# PS031       High
# PS032    College
# PS033       High
# PS034        NaN
# PS035     Middle
# PS036     Middle
# PS037       High
# PS039     Middle
# PS042     Middle
# PS046    Primary
# PS047       High
# PS049    Primary
# PS051    College
# PS054     Middle
# PS066       High
# PS067       High
# PS068    College
# PS070    College
# Name: education_level, dtype: object

# %%
df_clean.isnull().sum()
# Out:
# dx                         0
# age                        3
# sex                        2
# education_level            2
# heating_source             1
# smoke_6mos                 0
# age_start_smoking          7
# age_stop_smoking           8
# cigarettes_per_day         7
# liquor_freq                0
# family_hx_ugicancer        5
# temp_of_hot_beverages      0
# frequency_scalding_food    0
# height_cm                  0
# weight_kg                  0
# ps_id                      0
# wgs                        0
# dtype: int64

# %% [markdown]
# Great, now we can detect all our missing values.  Let's deal with missing data for the smoking-related columns.  First, let's make sure that the missing data in 'age_start_smoking' and 'age_stop_smoking' isn't due to that subject being a non-smoker.  How do we pull out all rows where any of the smoking-related columns are NaN?

# %%
df_clean[['smoke_6mos','age_start_smoking','age_stop_smoking','cigarettes_per_day']].isnull()
# Out:
#        smoke_6mos  age_start_smoking  age_stop_smoking  cigarettes_per_day
# id
# PS002       False              False              True               False
# PS003       False               True              True                True
# PS005       False               True              True                True
# PS007       False               True              True                True
# PS013       False              False             False               False
# PS015       False              False             False               False
# PS018       False              False             False               False
# PS019       False              False             False               False
# PS020       False              False             False               False
# PS021       False              False             False               False
# PS024       False              False             False               False
# PS025       False               True              True                True
# PS026       False               True              True                True
# PS028       False              False             False               False
# PS030       False              False             False               False
# PS031       False              False             False               False
# PS032       False              False             False               False
# PS033       False              False             False               False
# PS034       False              False             False               False
# PS035       False              False             False               False
# PS036       False              False             False               False
# PS037       False              False             False               False
# PS039       False              False             False               False
# PS042       False              False             False               False
# PS046       False              False             False               False
# PS047       False               True              True                True
# PS049       False              False             False               False
# PS051       False              False             False               False
# PS054       False               True              True                True
# PS066       False              False             False               False
# PS067       False              False             False               False
# PS068       False              False             False               False
# PS070       False              False             False               False

# %%
df_clean[['smoke_6mos','age_start_smoking','age_stop_smoking','cigarettes_per_day']].isnull().any(axis=1)
# Out:
# id
# PS002     True
# PS003     True
# PS005     True
# PS007     True
# PS013    False
# PS015    False
# PS018    False
# PS019    False
# PS020    False
# PS021    False
# PS024    False
# PS025     True
# PS026     True
# PS028    False
# PS030    False
# PS031    False
# PS032    False
# PS033    False
# PS034    False
# PS035    False
# PS036    False
# PS037    False
# PS039    False
# PS042    False
# PS046    False
# PS047     True
# PS049    False
# PS051    False
# PS054     True
# PS066    False
# PS067    False
# PS068    False
# PS070    False
# dtype: bool

# %%
df_clean[df_clean[['smoke_6mos','age_start_smoking','age_stop_smoking','cigarettes_per_day']].isnull().any(axis=1)]
# Out:
#                  dx   age sex education_level heating_source smoke_6mos  \
# id
# PS002          ESCC  53.0   M          Middle   Coal_product        Yes
# PS003          ESCC  63.0   F         College            Gas         No
# PS005          HGIN  59.0   F          Middle       Firewood         No
# PS007          ESCC  69.0   F            High            Gas         No
# PS025          HGIN  64.0   M            High            Gas         No
# PS026          ESCC  66.0   F         Primary            Gas         No
# PS047  Adenosq_ESCC  72.0   M            High           Coal         No
# PS054          HGIN  63.0   M          Middle   Coal_product         No
#
#        age_start_smoking  age_stop_smoking cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0               NaN                 20  Rarely-never
# PS003                NaN               NaN                NaN  Rarely-never
# PS005                NaN               NaN                NaN  Rarely-never
# PS007                NaN               NaN                NaN  Rarely-never
# PS025                NaN               NaN                NaN        Weekly
# PS026                NaN               NaN                NaN  Rarely-never
# PS047                NaN               NaN                NaN    Seasonally
# PS054                NaN               NaN                NaN  Rarely-never
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
# PS003                 Yes              Scalding                   Daily
# PS005                  No              Scalding                  Weekly
# PS007                  No              Scalding                   Daily
# PS025                 NaN                  Warm                   Daily
# PS026                  No                  Warm            Seldom-never
# PS047                 Yes                  Warm            Seldom-never
# PS054                  No              Scalding                   Daily
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002        170        110  PS-002  R12345
# PS003        161         56  PS-003  R12346
# PS005        159         63  PS-005  R12347
# PS007        160        110  PS-007  R12348
# PS025        167         63  PS-031   R126A
# PS026        160         45  PS-032   R126B
# PS047        183         88  PS-015   R126O
# PS054        170         63  PS-036   R126R

# %% [markdown]
# Looks like most of the missing data in these columns is because the individual was not a smoker.  Let's replace the one valid missing data field with the column mean.

# %%
stop_mean = round(df_clean['age_stop_smoking'].mean())
stop_mean
# Out:
# 53

# %%
df_clean.at['PS002','age_stop_smoking']=stop_mean

# %%
df_clean.loc[['PS002']]
# Out:
#          dx   age sex education_level heating_source smoke_6mos  \
# id
# PS002  ESCC  53.0   M          Middle   Coal_product        Yes
#
#        age_start_smoking  age_stop_smoking cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0              53.0                 20  Rarely-never
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002        170        110  PS-002  R12345

# %% [markdown]
# Now, let's impute the missing values for age by replacing with the column mean.

# %%
age_mean = round(df_clean['age'].mean())
age_mean
# Out:
# 59

# %%
df_clean['age'].fillna(age_mean, inplace=True)

# %%
df_clean.isnull().sum()
# Out:
# dx                         0
# age                        0
# sex                        2
# education_level            2
# heating_source             1
# smoke_6mos                 0
# age_start_smoking          7
# age_stop_smoking           7
# cigarettes_per_day         7
# liquor_freq                0
# family_hx_ugicancer        5
# temp_of_hot_beverages      0
# frequency_scalding_food    0
# height_cm                  0
# weight_kg                  0
# ps_id                      0
# wgs                        0
# dtype: int64

# %% [markdown]
# We could also opt to remove some data, either rows or columns, if there are missing values.

# %%
df_drop = df_clean.dropna() # drop rows
df_drop.shape
# Out:
# (19, 17)

# %%
df_drop
# Out:
#             dx   age sex education_level heating_source smoke_6mos  \
# id
# PS002     ESCC  53.0   M          Middle   Coal_product        Yes
# PS015     HGIN  59.0   M          Middle            Gas        Yes
# PS018     HGIN  58.0   M         Primary       Firewood        Yes
# PS021     HGIN  63.0   M          Middle            Gas        Yes
# PS028  Adenosq  54.0   M          Middle           Coal        Yes
# PS030     ESCC  60.0   M          Middle            Gas        Yes
# PS031     ESCC  59.0   M            High            Gas        Yes
# PS032     ESCC  56.0   M         College            Gas        Yes
# PS033     HGIN  47.0   M            High           Coal        Yes
# PS035     HGIN  59.0   M          Middle           Coal        Yes
# PS036     ESCC  53.0   M          Middle            Gas        Yes
# PS037     HGIN  53.0   M            High            Gas        Yes
# PS042     ESCC  67.0   M          Middle           Coal        Yes
# PS046     ESCC  62.0   M         Primary           Coal        Yes
# PS049     HGIN  67.0   M         Primary          Other        Yes
# PS066     HGIN  59.0   M            High            Gas        Yes
# PS067     ESCC  68.0   M            High            Gas        Yes
# PS068     ESCC  53.0   M         College           Coal        Yes
# PS070     HGIN  59.0   M         College           Coal        Yes
#
#        age_start_smoking  age_stop_smoking cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0              53.0                 20  Rarely-never
# PS015               18.0              57.0                 15         Daily
# PS018               26.0              58.0                 20         Daily
# PS021               20.0              63.0                 20         Daily
# PS028               18.0              54.0                 60        Weekly
# PS030               18.0              30.0                 40    Seasonally
# PS031               20.0              55.0                 20        Weekly
# PS032               24.0              55.0                 20       Monthly
# PS033               25.0              45.0                  8         Daily
# PS035               22.0              46.0                 40         Daily
# PS036               20.0              53.0                 40         Daily
# PS037               22.0              53.0                 20         Daily
# PS042               21.0              65.0                 20         Daily
# PS046               20.0              62.0                 30         Daily
# PS049               25.0              47.0                  3         Daily
# PS066               18.0              59.0                  6         Daily
# PS067               25.0              35.0                 20         Daily
# PS068               22.0              53.0                 35         Daily
# PS070               20.0              59.0                 20         Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
# PS015                 Yes                  Warm            Seldom-never
# PS018                  No                   Hot                   Daily
# PS021                  No                  Warm            Seldom-never
# PS028                  No              Scalding                   Daily
# PS030                  No              Scalding                   Daily
# PS031                  No                   Hot                   Daily
# PS032                  No              Scalding                  Weekly
# PS033                  No              Scalding                   Daily
# PS035                  No                   Hot                   Daily
# PS036                 Yes              Scalding                   Daily
# PS037                  No              Scalding                   Daily
# PS042                  No              Scalding                   Daily
# PS046                  No                  Warm            Seldom-never
# PS049                 Yes                  Warm            Seldom-never
# PS066                  No              Scalding                   Daily
# PS067                 Yes              Scalding                   Daily
# PS068                 Yes              Scalding                   Daily
# PS070                 Yes              Scalding                  Weekly
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002        170        110  PS-002  R12345
# PS015        176        150  PS-019   R1224
# PS018        170        156  PS-021   R1225
# PS021        773         75  PS-028   R1228
# PS028        175        150  PS-033   R126C
# PS030        173        140  PS-034   R126D
# PS031        173         75  PS-035   R126E
# PS032        175         80  PS-039   R126F
# PS033        180         85  PS-042   R126G
# PS035        170         74  PS-047   R126I
# PS036        176        130  PS-049   R126J
# PS037        172          5  PS-051   R126K
# PS042        179         80  PS-067   R126M
# PS046        177         75  PS-068   R126N
# PS049        177         73  PS-018   R126P
# PS066        180         70  PS-037   R126S
# PS067        173         63  PS-020   R126T
# PS068        176         93  PS-054   R126U
# PS070        170         79  PS-070   R126V

# %% [markdown]
# __Exercise: We used the mean of 'age' to fill in missing values in df_clean.  What if we wanted to use the median?__

# %%
age_median = round(df_clean['age'].median())
df_clean['age'].fillna(age_median, inplace=True)

# %% [markdown]
# ## 8.5.  Check for biologically unrealistic values

# %% [markdown]
# Sometimes, a value isn't technically missing, but it's clearly outside realistic expectations.  Let's check for examples of this.

# %%
df_clean['age'].describe()
# Out:
# count    33.000000
# mean     59.121212
# std       6.401941
# min      47.000000
# 25%      53.000000
# 50%      59.000000
# 75%      63.000000
# max      72.000000
# Name: age, dtype: float64

# %%
df_clean['height_cm'].describe()
# Out:
# count     33.00000
# mean     190.69697
# std      104.71792
# min      159.00000
# 25%      170.00000
# 50%      173.00000
# 75%      177.00000
# max      773.00000
# Name: height_cm, dtype: float64

# %%
df_clean['weight_kg'].describe()
# Out:
# count     33.000000
# mean      93.121212
# std       38.733672
# min        5.000000
# 25%       72.000000
# 50%       79.000000
# 75%      130.000000
# max      180.000000
# Name: weight_kg, dtype: float64

# %% [markdown]
# Uh oh!  It seems unlikely that someone would be 773 cm tall, or weigh 5 kg.  Look at a few quick plots to make sure there aren't other aberrant values like this.

# %%
import matplotlib.pyplot as plt

# %%
df_clean.boxplot()

# %%
df_clean['weight_kg'].hist()

# %%
df_clean['height_cm'].hist()

# %% [markdown]
# Looks like those two are the only obviously incorrect values.  Let's replace them with the mean (excluding the outlier) of the columns.

# %%
df_clean['height_cm'].replace(773, np.nan, inplace=True)

# %%
height_mean = round(df_clean['height_cm'].mean())
height_mean
# Out:
# 172

# %%
df_clean['height_cm'].replace(773, height_mean, inplace=True)

# %%
df_clean['weight_kg'].replace(5, np.nan, inplace=True)

# %%
weight_mean = round(df_clean['weight_kg'].mean())
weight_mean
# Out:
# 96

# %%
df_clean['weight_kg'].replace(5, weight_mean, inplace=True)

# %% [markdown]
# Now let's re-check the distributions, to make sure everything looks plausible.

# %%
df_clean.boxplot()

# %% [markdown]
# __Exercise: Take a closer look at the 'age' data by plotting a histogram.__

# %%
df_clean['age'].hist()

# %% [markdown]
# ## 8.6  Data types

# %% [markdown]
# Now that we've done a lot of work cleaning our data, let's make sure each column contains the expected data type.

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, PS002 to PS070
# Data columns (total 17 columns):
# dx                         33 non-null object
# age                        33 non-null float64
# sex                        31 non-null object
# education_level            31 non-null object
# heating_source             32 non-null object
# smoke_6mos                 33 non-null object
# age_start_smoking          26 non-null float64
# age_stop_smoking           26 non-null float64
# cigarettes_per_day         26 non-null object
# liquor_freq                33 non-null object
# family_hx_ugicancer        28 non-null object
# temp_of_hot_beverages      33 non-null object
# frequency_scalding_food    33 non-null object
# height_cm                  32 non-null float64
# weight_kg                  32 non-null float64
# ps_id                      33 non-null object
# wgs                        33 non-null object
# dtypes: float64(5), object(12)
# memory usage: 5.9+ KB

# %% [markdown]
# The column 'cigarettes_per_day' is listed as object, which is a string type.  Why?

# %%
df_clean['cigarettes_per_day'].value_counts()
# Out:
# 20    13
# 40     4
# 30     2
# 8      1
# 3      1
# 10     1
# 35     1
# 60     1
# 6      1
# 15     1
# Name: cigarettes_per_day, dtype: int64

# %%
df_clean['cigarettes_per_day']
# Out:
# id
# PS002     20
# PS003    NaN
# PS005    NaN
# PS007    NaN
# PS013     20
# PS015     15
# PS018     20
# PS019     20
# PS020     30
# PS021     20
# PS024     20
# PS025    NaN
# PS026    NaN
# PS028     60
# PS030     40
# PS031     20
# PS032     20
# PS033      8
# PS034     20
# PS035     40
# PS036     40
# PS037     20
# PS039     10
# PS042     20
# PS046     30
# PS047    NaN
# PS049      3
# PS051     40
# PS054    NaN
# PS066      6
# PS067     20
# PS068     35
# PS070     20
# Name: cigarettes_per_day, dtype: object

# %% [markdown]
# NaN is a float-representation of missing data; the other entries in this column are integers.  Let's change them all to floats.

# %%
df_clean['cigarettes_per_day'] = df_clean['cigarettes_per_day'].astype('float64')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, PS002 to PS070
# Data columns (total 17 columns):
# dx                         33 non-null object
# age                        33 non-null float64
# sex                        31 non-null object
# education_level            31 non-null object
# heating_source             32 non-null object
# smoke_6mos                 33 non-null object
# age_start_smoking          26 non-null float64
# age_stop_smoking           26 non-null float64
# cigarettes_per_day         26 non-null float64
# liquor_freq                33 non-null object
# family_hx_ugicancer        28 non-null object
# temp_of_hot_beverages      33 non-null object
# frequency_scalding_food    33 non-null object
# height_cm                  32 non-null float64
# weight_kg                  32 non-null float64
# ps_id                      33 non-null object
# wgs                        33 non-null object
# dtypes: float64(6), object(11)
# memory usage: 5.9+ KB

# %% [markdown]
# # 9.  Filter and group data

# %% [markdown]
# You can subset your dataframe using conditional selections.

# %% [markdown]
# First, let's see what happens if we make a conditional selection.

# %%
df_clean['heating_source'] == 'Coal'
# Out:
# id
# PS002    False
# PS003    False
# PS005    False
# PS007    False
# PS013    False
# PS015    False
# PS018    False
# PS019    False
# PS020    False
# PS021    False
# PS024    False
# PS025    False
# PS026    False
# PS028     True
# PS030    False
# PS031    False
# PS032    False
# PS033     True
# PS034     True
# PS035     True
# PS036    False
# PS037    False
# PS039     True
# PS042     True
# PS046     True
# PS047     True
# PS049    False
# PS051     True
# PS054    False
# PS066    False
# PS067    False
# PS068     True
# PS070     True
# Name: heating_source, dtype: bool

# %% [markdown]
# Now, let's apply that selection to the dataframe to retrieve the relevant rows.

# %%
df_clean[df_clean['heating_source'] == 'Coal']
# Out:
#                  dx   age  sex education_level heating_source smoke_6mos  \
# id
# PS028       Adenosq  54.0    M          Middle           Coal        Yes
# PS033          HGIN  47.0    M            High           Coal        Yes
# PS034          ESCC  48.0    M             NaN           Coal        Yes
# PS035          HGIN  59.0    M          Middle           Coal        Yes
# PS039          ESCC  51.0    M          Middle           Coal        Yes
# PS042          ESCC  67.0    M          Middle           Coal        Yes
# PS046          ESCC  62.0    M         Primary           Coal        Yes
# PS047  Adenosq_ESCC  72.0    M            High           Coal         No
# PS051          HGIN  52.0  NaN         College           Coal        Yes
# PS068          ESCC  53.0    M         College           Coal        Yes
# PS070          HGIN  59.0    M         College           Coal        Yes
#
#        age_start_smoking  age_stop_smoking  cigarettes_per_day liquor_freq  \
# id
# PS028               18.0              54.0                60.0      Weekly
# PS033               25.0              45.0                 8.0       Daily
# PS034               20.0              47.0                20.0       Daily
# PS035               22.0              46.0                40.0       Daily
# PS039               22.0              50.0                10.0     Monthly
# PS042               21.0              65.0                20.0       Daily
# PS046               20.0              62.0                30.0       Daily
# PS047                NaN               NaN                 NaN  Seasonally
# PS051               18.0              50.0                40.0       Daily
# PS068               22.0              53.0                35.0       Daily
# PS070               20.0              59.0                20.0       Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS028                  No              Scalding                   Daily
# PS033                  No              Scalding                   Daily
# PS034                  No              Scalding                   Daily
# PS035                  No                   Hot                   Daily
# PS039                 NaN                   Hot                   Daily
# PS042                  No              Scalding                   Daily
# PS046                  No                  Warm            Seldom-never
# PS047                 Yes                  Warm            Seldom-never
# PS051                 Yes              Scalding                   Daily
# PS068                 Yes              Scalding                   Daily
# PS070                 Yes              Scalding                  Weekly
#
#        height_cm  weight_kg   ps_id    wgs
# id
# PS028      175.0      150.0  PS-033  R126C
# PS033      180.0       85.0  PS-042  R126G
# PS034      176.0       72.0  PS-046  R126H
# PS035      170.0       74.0  PS-047  R126I
# PS039      170.0      140.0  PS-066  R126L
# PS042      179.0       80.0  PS-067  R126M
# PS046      177.0       75.0  PS-068  R126N
# PS047      183.0       88.0  PS-015  R126O
# PS051      170.0       75.0  PS-025  R126Q
# PS068      176.0       93.0  PS-054  R126U
# PS070      170.0       79.0  PS-070  R126V

# %% [markdown]
# __Exercise: Retrieve all rows from df_clean where the heating source is anything other than 'Coal'.__

# %%
df_clean[df_clean['heating_source'] != 'Coal']
# Out:
#          dx   age  sex education_level heating_source smoke_6mos  \
# id
# PS002  ESCC  53.0    M          Middle   Coal_product        Yes
# PS003  ESCC  63.0    F         College            Gas         No
# PS005  HGIN  59.0    F          Middle       Firewood         No
# PS007  ESCC  69.0    F            High            Gas         No
# PS013  ESCC  67.0    M             NaN            Gas        Yes
# PS015  HGIN  59.0    M          Middle            Gas        Yes
# PS018  HGIN  58.0    M         Primary       Firewood        Yes
# PS019  HGIN  59.0    M         College            Gas        Yes
# PS020  HGIN  59.0    M         College            Gas        Yes
# PS021  HGIN  63.0    M          Middle            Gas        Yes
# PS024  HGIN  50.0  NaN         Primary            NaN        Yes
# PS025  HGIN  64.0    M            High            Gas         No
# PS026  ESCC  66.0    F         Primary            Gas         No
# PS030  ESCC  60.0    M          Middle            Gas        Yes
# PS031  ESCC  59.0    M            High            Gas        Yes
# PS032  ESCC  56.0    M         College            Gas        Yes
# PS036  ESCC  53.0    M          Middle            Gas        Yes
# PS037  HGIN  53.0    M            High            Gas        Yes
# PS049  HGIN  67.0    M         Primary          Other        Yes
# PS054  HGIN  63.0    M          Middle   Coal_product         No
# PS066  HGIN  59.0    M            High            Gas        Yes
# PS067  ESCC  68.0    M            High            Gas        Yes
#
#        age_start_smoking  age_stop_smoking  cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0              53.0                20.0  Rarely-never
# PS003                NaN               NaN                 NaN  Rarely-never
# PS005                NaN               NaN                 NaN  Rarely-never
# PS007                NaN               NaN                 NaN  Rarely-never
# PS013               36.0              57.0                20.0         Daily
# PS015               18.0              57.0                15.0         Daily
# PS018               26.0              58.0                20.0         Daily
# PS019               22.0              55.0                20.0         Daily
# PS020               22.0              65.0                30.0         Daily
# PS021               20.0              63.0                20.0         Daily
# PS024               20.0              50.0                20.0  Rarely-never
# PS025                NaN               NaN                 NaN        Weekly
# PS026                NaN               NaN                 NaN  Rarely-never
# PS030               18.0              30.0                40.0    Seasonally
# PS031               20.0              55.0                20.0        Weekly
# PS032               24.0              55.0                20.0       Monthly
# PS036               20.0              53.0                40.0         Daily
# PS037               22.0              53.0                20.0         Daily
# PS049               25.0              47.0                 3.0         Daily
# PS054                NaN               NaN                 NaN  Rarely-never
# PS066               18.0              59.0                 6.0         Daily
# PS067               25.0              35.0                20.0         Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
# PS003                 Yes              Scalding                   Daily
# PS005                  No              Scalding                  Weekly
# PS007                  No              Scalding                   Daily
# PS013                  No                  Warm            Occasionally
# PS015                 Yes                  Warm            Seldom-never
# PS018                  No                   Hot                   Daily
# PS019                 NaN                   Hot                   Daily
# PS020                 NaN                   Hot                   Daily
# PS021                  No                  Warm            Seldom-never
# PS024                 NaN              Scalding                   Daily
# PS025                 NaN                  Warm                   Daily
# PS026                  No                  Warm            Seldom-never
# PS030                  No              Scalding                   Daily
# PS031                  No                   Hot                   Daily
# PS032                  No              Scalding                  Weekly
# PS036                 Yes              Scalding                   Daily
# PS037                  No              Scalding                   Daily
# PS049                 Yes                  Warm            Seldom-never
# PS054                  No              Scalding                   Daily
# PS066                  No              Scalding                   Daily
# PS067                 Yes              Scalding                   Daily
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002      170.0      110.0  PS-002  R12345
# PS003      161.0       56.0  PS-003  R12346
# PS005      159.0       63.0  PS-005  R12347
# PS007      160.0      110.0  PS-007  R12348
# PS013      184.0      180.0  PS-013   R1223
# PS015      176.0      150.0  PS-019   R1224
# PS018      170.0      156.0  PS-021   R1225
# PS019      172.0      130.0  PS-024   R1226
# PS020      177.0      150.0  PS-026   R1227
# PS021        NaN       75.0  PS-028   R1228
# PS024      169.0       75.0  PS-030   R1229
# PS025      167.0       63.0  PS-031   R126A
# PS026      160.0       45.0  PS-032   R126B
# PS030      173.0      140.0  PS-034   R126D
# PS031      173.0       75.0  PS-035   R126E
# PS032      175.0       80.0  PS-039   R126F
# PS036      176.0      130.0  PS-049   R126J
# PS037      172.0        NaN  PS-051   R126K
# PS049      177.0       73.0  PS-018   R126P
# PS054      170.0       63.0  PS-036   R126R
# PS066      180.0       70.0  PS-037   R126S
# PS067      173.0       63.0  PS-020   R126T

# %% [markdown]
# You can also select continuous variables in a similar way.

# %%
df_clean[df_clean['age'] > 65]
# Out:
#                  dx   age sex education_level heating_source smoke_6mos  \
# id
# PS007          ESCC  69.0   F            High            Gas         No
# PS013          ESCC  67.0   M             NaN            Gas        Yes
# PS026          ESCC  66.0   F         Primary            Gas         No
# PS042          ESCC  67.0   M          Middle           Coal        Yes
# PS047  Adenosq_ESCC  72.0   M            High           Coal         No
# PS049          HGIN  67.0   M         Primary          Other        Yes
# PS067          ESCC  68.0   M            High            Gas        Yes
#
#        age_start_smoking  age_stop_smoking  cigarettes_per_day   liquor_freq  \
# id
# PS007                NaN               NaN                 NaN  Rarely-never
# PS013               36.0              57.0                20.0         Daily
# PS026                NaN               NaN                 NaN  Rarely-never
# PS042               21.0              65.0                20.0         Daily
# PS047                NaN               NaN                 NaN    Seasonally
# PS049               25.0              47.0                 3.0         Daily
# PS067               25.0              35.0                20.0         Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS007                  No              Scalding                   Daily
# PS013                  No                  Warm            Occasionally
# PS026                  No                  Warm            Seldom-never
# PS042                  No              Scalding                   Daily
# PS047                 Yes                  Warm            Seldom-never
# PS049                 Yes                  Warm            Seldom-never
# PS067                 Yes              Scalding                   Daily
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS007      160.0      110.0  PS-007  R12348
# PS013      184.0      180.0  PS-013   R1223
# PS026      160.0       45.0  PS-032   R126B
# PS042      179.0       80.0  PS-067   R126M
# PS047      183.0       88.0  PS-015   R126O
# PS049      177.0       73.0  PS-018   R126P
# PS067      173.0       63.0  PS-020   R126T

# %% [markdown]
# You can apply multiple criteria to your selection using or (`|`) or and (`&`).  Note the use of parentheses to group conditional statements.

# %%
df_clean[(df_clean['temp_of_hot_beverages'] == 'Scalding') | (df_clean['temp_of_hot_beverages'] == 'Hot')]
# Out:
#             dx   age  sex education_level heating_source smoke_6mos  \
# id
# PS002     ESCC  53.0    M          Middle   Coal_product        Yes
# PS003     ESCC  63.0    F         College            Gas         No
# PS005     HGIN  59.0    F          Middle       Firewood         No
# PS007     ESCC  69.0    F            High            Gas         No
# PS018     HGIN  58.0    M         Primary       Firewood        Yes
# PS019     HGIN  59.0    M         College            Gas        Yes
# PS020     HGIN  59.0    M         College            Gas        Yes
# PS024     HGIN  50.0  NaN         Primary            NaN        Yes
# PS028  Adenosq  54.0    M          Middle           Coal        Yes
# PS030     ESCC  60.0    M          Middle            Gas        Yes
# PS031     ESCC  59.0    M            High            Gas        Yes
# PS032     ESCC  56.0    M         College            Gas        Yes
# PS033     HGIN  47.0    M            High           Coal        Yes
# PS034     ESCC  48.0    M             NaN           Coal        Yes
# PS035     HGIN  59.0    M          Middle           Coal        Yes
# PS036     ESCC  53.0    M          Middle            Gas        Yes
# PS037     HGIN  53.0    M            High            Gas        Yes
# PS039     ESCC  51.0    M          Middle           Coal        Yes
# PS042     ESCC  67.0    M          Middle           Coal        Yes
# PS051     HGIN  52.0  NaN         College           Coal        Yes
# PS054     HGIN  63.0    M          Middle   Coal_product         No
# PS066     HGIN  59.0    M            High            Gas        Yes
# PS067     ESCC  68.0    M            High            Gas        Yes
# PS068     ESCC  53.0    M         College           Coal        Yes
# PS070     HGIN  59.0    M         College           Coal        Yes
#
#        age_start_smoking  age_stop_smoking  cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0              53.0                20.0  Rarely-never
# PS003                NaN               NaN                 NaN  Rarely-never
# PS005                NaN               NaN                 NaN  Rarely-never
# PS007                NaN               NaN                 NaN  Rarely-never
# PS018               26.0              58.0                20.0         Daily
# PS019               22.0              55.0                20.0         Daily
# PS020               22.0              65.0                30.0         Daily
# PS024               20.0              50.0                20.0  Rarely-never
# PS028               18.0              54.0                60.0        Weekly
# PS030               18.0              30.0                40.0    Seasonally
# PS031               20.0              55.0                20.0        Weekly
# PS032               24.0              55.0                20.0       Monthly
# PS033               25.0              45.0                 8.0         Daily
# PS034               20.0              47.0                20.0         Daily
# PS035               22.0              46.0                40.0         Daily
# PS036               20.0              53.0                40.0         Daily
# PS037               22.0              53.0                20.0         Daily
# PS039               22.0              50.0                10.0       Monthly
# PS042               21.0              65.0                20.0         Daily
# PS051               18.0              50.0                40.0         Daily
# PS054                NaN               NaN                 NaN  Rarely-never
# PS066               18.0              59.0                 6.0         Daily
# PS067               25.0              35.0                20.0         Daily
# PS068               22.0              53.0                35.0         Daily
# PS070               20.0              59.0                20.0         Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
# PS003                 Yes              Scalding                   Daily
# PS005                  No              Scalding                  Weekly
# PS007                  No              Scalding                   Daily
# PS018                  No                   Hot                   Daily
# PS019                 NaN                   Hot                   Daily
# PS020                 NaN                   Hot                   Daily
# PS024                 NaN              Scalding                   Daily
# PS028                  No              Scalding                   Daily
# PS030                  No              Scalding                   Daily
# PS031                  No                   Hot                   Daily
# PS032                  No              Scalding                  Weekly
# PS033                  No              Scalding                   Daily
# PS034                  No              Scalding                   Daily
# PS035                  No                   Hot                   Daily
# PS036                 Yes              Scalding                   Daily
# PS037                  No              Scalding                   Daily
# PS039                 NaN                   Hot                   Daily
# PS042                  No              Scalding                   Daily
# PS051                 Yes              Scalding                   Daily
# PS054                  No              Scalding                   Daily
# PS066                  No              Scalding                   Daily
# PS067                 Yes              Scalding                   Daily
# PS068                 Yes              Scalding                   Daily
# PS070                 Yes              Scalding                  Weekly
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002      170.0      110.0  PS-002  R12345
# PS003      161.0       56.0  PS-003  R12346
# PS005      159.0       63.0  PS-005  R12347
# PS007      160.0      110.0  PS-007  R12348
# PS018      170.0      156.0  PS-021   R1225
# PS019      172.0      130.0  PS-024   R1226
# PS020      177.0      150.0  PS-026   R1227
# PS024      169.0       75.0  PS-030   R1229
# PS028      175.0      150.0  PS-033   R126C
# PS030      173.0      140.0  PS-034   R126D
# PS031      173.0       75.0  PS-035   R126E
# PS032      175.0       80.0  PS-039   R126F
# PS033      180.0       85.0  PS-042   R126G
# PS034      176.0       72.0  PS-046   R126H
# PS035      170.0       74.0  PS-047   R126I
# PS036      176.0      130.0  PS-049   R126J
# PS037      172.0        NaN  PS-051   R126K
# PS039      170.0      140.0  PS-066   R126L
# PS042      179.0       80.0  PS-067   R126M
# PS051      170.0       75.0  PS-025   R126Q
# PS054      170.0       63.0  PS-036   R126R
# PS066      180.0       70.0  PS-037   R126S
# PS067      173.0       63.0  PS-020   R126T
# PS068      176.0       93.0  PS-054   R126U
# PS070      170.0       79.0  PS-070   R126V

# %% [markdown]
# Using `.isin()` is more concise than the above command, but does the same thing.

# %%
df_clean[df_clean['temp_of_hot_beverages'].isin(['Scalding', 'Hot'])]
# Out:
#             dx   age  sex education_level heating_source smoke_6mos  \
# id
# PS002     ESCC  53.0    M          Middle   Coal_product        Yes
# PS003     ESCC  63.0    F         College            Gas         No
# PS005     HGIN  59.0    F          Middle       Firewood         No
# PS007     ESCC  69.0    F            High            Gas         No
# PS018     HGIN  58.0    M         Primary       Firewood        Yes
# PS019     HGIN  59.0    M         College            Gas        Yes
# PS020     HGIN  59.0    M         College            Gas        Yes
# PS024     HGIN  50.0  NaN         Primary            NaN        Yes
# PS028  Adenosq  54.0    M          Middle           Coal        Yes
# PS030     ESCC  60.0    M          Middle            Gas        Yes
# PS031     ESCC  59.0    M            High            Gas        Yes
# PS032     ESCC  56.0    M         College            Gas        Yes
# PS033     HGIN  47.0    M            High           Coal        Yes
# PS034     ESCC  48.0    M             NaN           Coal        Yes
# PS035     HGIN  59.0    M          Middle           Coal        Yes
# PS036     ESCC  53.0    M          Middle            Gas        Yes
# PS037     HGIN  53.0    M            High            Gas        Yes
# PS039     ESCC  51.0    M          Middle           Coal        Yes
# PS042     ESCC  67.0    M          Middle           Coal        Yes
# PS051     HGIN  52.0  NaN         College           Coal        Yes
# PS054     HGIN  63.0    M          Middle   Coal_product         No
# PS066     HGIN  59.0    M            High            Gas        Yes
# PS067     ESCC  68.0    M            High            Gas        Yes
# PS068     ESCC  53.0    M         College           Coal        Yes
# PS070     HGIN  59.0    M         College           Coal        Yes
#
#        age_start_smoking  age_stop_smoking  cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0              53.0                20.0  Rarely-never
# PS003                NaN               NaN                 NaN  Rarely-never
# PS005                NaN               NaN                 NaN  Rarely-never
# PS007                NaN               NaN                 NaN  Rarely-never
# PS018               26.0              58.0                20.0         Daily
# PS019               22.0              55.0                20.0         Daily
# PS020               22.0              65.0                30.0         Daily
# PS024               20.0              50.0                20.0  Rarely-never
# PS028               18.0              54.0                60.0        Weekly
# PS030               18.0              30.0                40.0    Seasonally
# PS031               20.0              55.0                20.0        Weekly
# PS032               24.0              55.0                20.0       Monthly
# PS033               25.0              45.0                 8.0         Daily
# PS034               20.0              47.0                20.0         Daily
# PS035               22.0              46.0                40.0         Daily
# PS036               20.0              53.0                40.0         Daily
# PS037               22.0              53.0                20.0         Daily
# PS039               22.0              50.0                10.0       Monthly
# PS042               21.0              65.0                20.0         Daily
# PS051               18.0              50.0                40.0         Daily
# PS054                NaN               NaN                 NaN  Rarely-never
# PS066               18.0              59.0                 6.0         Daily
# PS067               25.0              35.0                20.0         Daily
# PS068               22.0              53.0                35.0         Daily
# PS070               20.0              59.0                20.0         Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
# PS003                 Yes              Scalding                   Daily
# PS005                  No              Scalding                  Weekly
# PS007                  No              Scalding                   Daily
# PS018                  No                   Hot                   Daily
# PS019                 NaN                   Hot                   Daily
# PS020                 NaN                   Hot                   Daily
# PS024                 NaN              Scalding                   Daily
# PS028                  No              Scalding                   Daily
# PS030                  No              Scalding                   Daily
# PS031                  No                   Hot                   Daily
# PS032                  No              Scalding                  Weekly
# PS033                  No              Scalding                   Daily
# PS034                  No              Scalding                   Daily
# PS035                  No                   Hot                   Daily
# PS036                 Yes              Scalding                   Daily
# PS037                  No              Scalding                   Daily
# PS039                 NaN                   Hot                   Daily
# PS042                  No              Scalding                   Daily
# PS051                 Yes              Scalding                   Daily
# PS054                  No              Scalding                   Daily
# PS066                  No              Scalding                   Daily
# PS067                 Yes              Scalding                   Daily
# PS068                 Yes              Scalding                   Daily
# PS070                 Yes              Scalding                  Weekly
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002      170.0      110.0  PS-002  R12345
# PS003      161.0       56.0  PS-003  R12346
# PS005      159.0       63.0  PS-005  R12347
# PS007      160.0      110.0  PS-007  R12348
# PS018      170.0      156.0  PS-021   R1225
# PS019      172.0      130.0  PS-024   R1226
# PS020      177.0      150.0  PS-026   R1227
# PS024      169.0       75.0  PS-030   R1229
# PS028      175.0      150.0  PS-033   R126C
# PS030      173.0      140.0  PS-034   R126D
# PS031      173.0       75.0  PS-035   R126E
# PS032      175.0       80.0  PS-039   R126F
# PS033      180.0       85.0  PS-042   R126G
# PS034      176.0       72.0  PS-046   R126H
# PS035      170.0       74.0  PS-047   R126I
# PS036      176.0      130.0  PS-049   R126J
# PS037      172.0        NaN  PS-051   R126K
# PS039      170.0      140.0  PS-066   R126L
# PS042      179.0       80.0  PS-067   R126M
# PS051      170.0       75.0  PS-025   R126Q
# PS054      170.0       63.0  PS-036   R126R
# PS066      180.0       70.0  PS-037   R126S
# PS067      173.0       63.0  PS-020   R126T
# PS068      176.0       93.0  PS-054   R126U
# PS070      170.0       79.0  PS-070   R126V

# %% [markdown]
# This is an `&` example.

# %%
df_clean[(df_clean['temp_of_hot_beverages'] == 'Scalding') & (df_clean['frequency_scalding_food'] == 'Daily')]
# Out:
#             dx   age  sex education_level heating_source smoke_6mos  \
# id
# PS002     ESCC  53.0    M          Middle   Coal_product        Yes
# PS003     ESCC  63.0    F         College            Gas         No
# PS007     ESCC  69.0    F            High            Gas         No
# PS024     HGIN  50.0  NaN         Primary            NaN        Yes
# PS028  Adenosq  54.0    M          Middle           Coal        Yes
# PS030     ESCC  60.0    M          Middle            Gas        Yes
# PS033     HGIN  47.0    M            High           Coal        Yes
# PS034     ESCC  48.0    M             NaN           Coal        Yes
# PS036     ESCC  53.0    M          Middle            Gas        Yes
# PS037     HGIN  53.0    M            High            Gas        Yes
# PS042     ESCC  67.0    M          Middle           Coal        Yes
# PS051     HGIN  52.0  NaN         College           Coal        Yes
# PS054     HGIN  63.0    M          Middle   Coal_product         No
# PS066     HGIN  59.0    M            High            Gas        Yes
# PS067     ESCC  68.0    M            High            Gas        Yes
# PS068     ESCC  53.0    M         College           Coal        Yes
#
#        age_start_smoking  age_stop_smoking  cigarettes_per_day   liquor_freq  \
# id
# PS002               20.0              53.0                20.0  Rarely-never
# PS003                NaN               NaN                 NaN  Rarely-never
# PS007                NaN               NaN                 NaN  Rarely-never
# PS024               20.0              50.0                20.0  Rarely-never
# PS028               18.0              54.0                60.0        Weekly
# PS030               18.0              30.0                40.0    Seasonally
# PS033               25.0              45.0                 8.0         Daily
# PS034               20.0              47.0                20.0         Daily
# PS036               20.0              53.0                40.0         Daily
# PS037               22.0              53.0                20.0         Daily
# PS042               21.0              65.0                20.0         Daily
# PS051               18.0              50.0                40.0         Daily
# PS054                NaN               NaN                 NaN  Rarely-never
# PS066               18.0              59.0                 6.0         Daily
# PS067               25.0              35.0                20.0         Daily
# PS068               22.0              53.0                35.0         Daily
#
#       family_hx_ugicancer temp_of_hot_beverages frequency_scalding_food  \
# id
# PS002                  No              Scalding                   Daily
# PS003                 Yes              Scalding                   Daily
# PS007                  No              Scalding                   Daily
# PS024                 NaN              Scalding                   Daily
# PS028                  No              Scalding                   Daily
# PS030                  No              Scalding                   Daily
# PS033                  No              Scalding                   Daily
# PS034                  No              Scalding                   Daily
# PS036                 Yes              Scalding                   Daily
# PS037                  No              Scalding                   Daily
# PS042                  No              Scalding                   Daily
# PS051                 Yes              Scalding                   Daily
# PS054                  No              Scalding                   Daily
# PS066                  No              Scalding                   Daily
# PS067                 Yes              Scalding                   Daily
# PS068                 Yes              Scalding                   Daily
#
#        height_cm  weight_kg   ps_id     wgs
# id
# PS002      170.0      110.0  PS-002  R12345
# PS003      161.0       56.0  PS-003  R12346
# PS007      160.0      110.0  PS-007  R12348
# PS024      169.0       75.0  PS-030   R1229
# PS028      175.0      150.0  PS-033   R126C
# PS030      173.0      140.0  PS-034   R126D
# PS033      180.0       85.0  PS-042   R126G
# PS034      176.0       72.0  PS-046   R126H
# PS036      176.0      130.0  PS-049   R126J
# PS037      172.0        NaN  PS-051   R126K
# PS042      179.0       80.0  PS-067   R126M
# PS051      170.0       75.0  PS-025   R126Q
# PS054      170.0       63.0  PS-036   R126R
# PS066      180.0       70.0  PS-037   R126S
# PS067      173.0       63.0  PS-020   R126T
# PS068      176.0       93.0  PS-054   R126U

# %% [markdown]
# You can group your data using `groupby()`.  For example, let's say we want to calculate the mean age for each category of "temp_of_hot_beverages."

# %%
df_clean.groupby(['temp_of_hot_beverages'])['age'].mean()
# Out:
# temp_of_hot_beverages
# Hot         57.500000
# Scalding    57.157895
# Warm        65.000000
# Name: age, dtype: float64

# %% [markdown]
# __Exercise: Now that we know `.groupby()`, how could we have used it to check that non-smoking status ('smoke_6mos') correlates correctly with missing values for 'age_start_smoking', 'age_stop_smoking', and 'cigarettes_per_day?'__

# %%
df_clean.groupby(['smoke_6mos'])['age_start_smoking', 'age_stop_smoking', 'cigarettes_per_day'].mean()
# Out:
#             age_start_smoking  age_stop_smoking  cigarettes_per_day
# smoke_6mos
# No                        NaN               NaN                 NaN
# Yes                 21.692308         52.923077           23.730769

# %% [markdown]
# # 10.  Apply filters, groupby, etc. to generate insightful plots

# %% [markdown]
# First, let's plot what we just calculated, the mean age for each category of "temp_of_hot_beverages."

# %%
df_clean.groupby(['temp_of_hot_beverages'])['age'].mean().plot.bar()

# %% [markdown]
# How much do our subjects drink?  Let's use `.value_counts()` to determine how many instances there are of each "liquor_freq" category, and plot the result.

# %%
df_clean['liquor_freq'].value_counts()
# Out:
# Daily           19
# Rarely-never     7
# Weekly           3
# Seasonally       2
# Monthly          2
# Name: liquor_freq, dtype: int64

# %%
df_clean['liquor_freq'].value_counts().plot.bar()

# %% [markdown]
# Let's combine filtering and plotting to look at the distribution of smokers' start and stop ages, amongst subjects who drink scalding beverages.

# %%
df_clean[df_clean['temp_of_hot_beverages'] == 'Scalding'].boxplot(column=['age_start_smoking','age_stop_smoking'])

# %% [markdown]
# Let's use `groupby()` again, this time to look at the means for all continous variables, grouped by education level.

# %%
df_clean.groupby(['education_level']).mean().plot.bar(figsize=[10,5])

# %% [markdown]
# That's a rather busy graph - let's redraw it, just focusing on smoking start/stop ages.  Do you think there's likely to be a difference in start/stop age across different levels of education?

# %%
df_clean.groupby(['education_level'])['age_start_smoking','age_stop_smoking'].mean().plot.bar(figsize=[10,5])

# %% [markdown]
# We can create scatter plots to look at the interaction between multiple features.  Here, let's look at height and weight.

# %%
df_clean.plot.scatter('height_cm','weight_kg')

# %% [markdown]
# We can use `corr()` to look for correlations within our data.  Without any additional parameters, this will compare all continuous variables in your dataframe.

# %%
df_clean.corr()
# Out:
#                          age  age_start_smoking  age_stop_smoking  \
# age                 1.000000           0.342724          0.145876
# age_start_smoking   0.342724           1.000000         -0.005996
# age_stop_smoking    0.145876          -0.005996          1.000000
# cigarettes_per_day -0.141863          -0.303052         -0.107352
# height_cm          -0.049027           0.403722          0.255567
# weight_kg          -0.138566           0.299374          0.112891
#
#                     cigarettes_per_day  height_cm  weight_kg
# age                          -0.141863  -0.049027  -0.138566
# age_start_smoking            -0.303052   0.403722   0.299374
# age_stop_smoking             -0.107352   0.255567   0.112891
# cigarettes_per_day            1.000000  -0.185545   0.235612
# height_cm                    -0.185545   1.000000   0.342458
# weight_kg                     0.235612   0.342458   1.000000

# %% [markdown]
# There are lots of ways to create a heatmap from this data.  Here's just one simple one, that doesn't rely on any additional libraries.

# %%
df_clean.corr().style.background_gradient(cmap='autumn')
# Out:
# <style  type="text/css" >
#     #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col0 {
#             background-color:  #ffff00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col1 {
#             background-color:  #ff7e00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col2 {
#             background-color:  #ff3a00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col3 {
#             background-color:  #ff1f00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col4 {
#             background-color:  #ff1d00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col5 {
#             background-color:  #ff0000;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col0 {
#             background-color:  #ff6c00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col1 {
#             background-color:  #ffff00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col2 {
#             background-color:  #ff1700;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col3 {
#             background-color:  #ff0000;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col4 {
#             background-color:  #ff7f00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col5 {
#             background-color:  #ff6200;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col0 {
#             background-color:  #ff4000;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col1 {
#             background-color:  #ff3a00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col2 {
#             background-color:  #ffff00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col3 {
#             background-color:  #ff2600;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col4 {
#             background-color:  #ff5f00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col5 {
#             background-color:  #ff3800;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col0 {
#             background-color:  #ff0000;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col1 {
#             background-color:  #ff0000;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col2 {
#             background-color:  #ff0000;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col3 {
#             background-color:  #ffff00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col4 {
#             background-color:  #ff0000;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col5 {
#             background-color:  #ff5400;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col0 {
#             background-color:  #ff1400;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col1 {
#             background-color:  #ff8a00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col2 {
#             background-color:  #ff5300;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col3 {
#             background-color:  #ff1700;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col4 {
#             background-color:  #ffff00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col5 {
#             background-color:  #ff6c00;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow5_col0 {
#             background-color:  #ff0000;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow5_col1 {
#             background-color:  #ff7600;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow5_col2 {
#             background-color:  #ff3200;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow5_col3 {
#             background-color:  #ff6900;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow5_col4 {
#             background-color:  #ff7200;
#         }    #T_b7bed52e_9118_11e9_a4b0_9801a7af805drow5_col5 {
#             background-color:  #ffff00;
#         }</style>
# <table id="T_b7bed52e_9118_11e9_a4b0_9801a7af805d" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >age</th>
#         <th class="col_heading level0 col1" >age_start_smoking</th>
#         <th class="col_heading level0 col2" >age_stop_smoking</th>
#         <th class="col_heading level0 col3" >cigarettes_per_day</th>
#         <th class="col_heading level0 col4" >height_cm</th>
#         <th class="col_heading level0 col5" >weight_kg</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b7bed52e_9118_11e9_a4b0_9801a7af805dlevel0_row0" class="row_heading level0 row0" >age</th>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col0" class="data row0 col0" >1</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col1" class="data row0 col1" >0.342724</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col2" class="data row0 col2" >0.145876</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col3" class="data row0 col3" >-0.141863</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col4" class="data row0 col4" >-0.0490266</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow0_col5" class="data row0 col5" >-0.138566</td>
#     </tr>    <tr>
#         <th id="T_b7bed52e_9118_11e9_a4b0_9801a7af805dlevel0_row1" class="row_heading level0 row1" >age_start_smoking</th>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col0" class="data row1 col0" >0.342724</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col1" class="data row1 col1" >1</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col2" class="data row1 col2" >-0.00599615</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col3" class="data row1 col3" >-0.303052</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col4" class="data row1 col4" >0.403722</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow1_col5" class="data row1 col5" >0.299374</td>
#     </tr>    <tr>
#         <th id="T_b7bed52e_9118_11e9_a4b0_9801a7af805dlevel0_row2" class="row_heading level0 row2" >age_stop_smoking</th>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col0" class="data row2 col0" >0.145876</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col1" class="data row2 col1" >-0.00599615</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col2" class="data row2 col2" >1</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col3" class="data row2 col3" >-0.107352</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col4" class="data row2 col4" >0.255567</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow2_col5" class="data row2 col5" >0.112891</td>
#     </tr>    <tr>
#         <th id="T_b7bed52e_9118_11e9_a4b0_9801a7af805dlevel0_row3" class="row_heading level0 row3" >cigarettes_per_day</th>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col0" class="data row3 col0" >-0.141863</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col1" class="data row3 col1" >-0.303052</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col2" class="data row3 col2" >-0.107352</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col3" class="data row3 col3" >1</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col4" class="data row3 col4" >-0.185545</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow3_col5" class="data row3 col5" >0.235612</td>
#     </tr>    <tr>
#         <th id="T_b7bed52e_9118_11e9_a4b0_9801a7af805dlevel0_row4" class="row_heading level0 row4" >height_cm</th>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col0" class="data row4 col0" >-0.0490266</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col1" class="data row4 col1" >0.403722</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col2" class="data row4 col2" >0.255567</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col3" class="data row4 col3" >-0.185545</td>
#         <td id="T_b7bed52e_9118_11e9_a4b0_9801a7af805drow4_col4" class="data row4 col4" >1</td>
#         <td i

# %% [markdown]
# __Exercise: Generate a scatter plot of any two continuous variables.__

# %%
df_clean.plot.scatter('age_start_smoking','cigarettes_per_day')

# %% [markdown]
# __Exercise: Plot the distribution of all continuous variables for subjects below 65 and above 65.__

# %%
df_clean[df_clean['age'] >= 65].boxplot()

# %%
df_clean[df_clean['age'] < 65].boxplot()

# %% [markdown]
# # 11.  Conclusions

# %% [markdown]
# Make sure to download the notebook if you've made changes and want to save them!  If you re-open the binder link, it will be reset to the way you originally found it.
#
# Already use Excel, and want to start using pandas on your own?  Try this challenge: open your data in Excel and read it into pandas.  For every action you perform in Excel, do the equivalent thing in pandas.
